# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# !unzip \dataset.zip

# %%
import os

base_dir = "C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
classes = ["Sirih","Seledri","Pepaya","Pandan","Nangka","Lidah buaya","Kemangi","Jeruk","Jambu biji","Belimbing Wuluh"]

sirih_train_path = os.path.join(train_dir, 'Sirih')
seledri_train_path = os.path.join(train_dir, 'Seledri')
pepaya_train_path = os.path.join(train_dir, 'Pepaya')
pandan_train_path = os.path.join(train_dir, 'Pandan')
nangka_train_path = os.path.join(train_dir, 'Nangka')
lidahbuaya_train_path = os.path.join(train_dir, 'Lidah buaya')
kemangi_train_path = os.path.join(train_dir, 'Kemangi')
jeruk_train_path = os.path.join(train_dir, 'Jeruk')
jambubiji_train_path = os.path.join(train_dir, 'Jambu biji')
belimbingwuluh_train_path = os.path.join(train_dir, 'Belimbing Wuluh')

sirih_val_path = os.path.join(val_dir, 'Sirih')
seledri_val_path = os.path.join(val_dir, 'Seledri')
pepaya_val_path = os.path.join(val_dir, 'Pepaya')
pandan_val_path = os.path.join(val_dir, 'Pandan')
nangka_val_path = os.path.join(val_dir, 'Nangka')
lidahbuaya_val_path = os.path.join(val_dir, 'Lidah buaya')
kemangi_val_path = os.path.join(val_dir, 'Kemangi')
jeruk_val_path = os.path.join(val_dir, 'Jeruk')
jambubiji_val_path = os.path.join(val_dir, 'Jambu biji')
belimbingwuluh_val_path = os.path.join(val_dir, 'Belimbing Wuluh')

len_sirih_train = len(os.listdir(sirih_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_jambubiji_train = len(os.listdir(jambubiji_train_path))
len_belimbingwuluh_train = len(os.listdir(belimbingwuluh_train_path))

len_sirih_val = len(os.listdir(sirih_val_path))
len_seledri_val = len(os.listdir(seledri_val_path))
len_pepaya_val = len(os.listdir(pepaya_val_path))
len_pandan_val = len(os.listdir(pandan_val_path))
len_nangka_val = len(os.listdir(nangka_val_path))
len_lidahbuaya_val = len(os.listdir(lidahbuaya_val_path))
len_kemangi_val = len(os.listdir(kemangi_val_path))
len_jeruk_val = len(os.listdir(jeruk_val_path))
len_jambubiji_val = len(os.listdir(jambubiji_val_path))
len_belimbingwuluh_val = len(os.listdir(belimbingwuluh_val_path))

print("Panjang train:", str(len_sirih_train + len_seledri_train + len_pepaya_train + len_pandan_train + len_nangka_train + len_lidahbuaya_train + len_kemangi_train + len_jeruk_train + len_jambubiji_train + len_belimbingwuluh_train))
print("Panjang validation:", str(len_sirih_val + len_seledri_val + len_pepaya_val + len_pandan_val + len_nangka_val + len_lidahbuaya_val + len_kemangi_val + len_jeruk_val + len_jambubiji_val + len_belimbingwuluh_val))

print('''\n==== Jumlah data train ====
Panjang data train Sirih: {}
Panjang data train Peledri: {}
Panjang data train Pepaya: {}
Panjang data train Pandan: {}
Panjang data train Nangka: {}
Panjang data train Lidah Buaya: {}
Panjang data train Kemangi: {}
Panjang data train Jeruk: {}
Panjang data train Jambu Biji: {}
Panjang data train Belimbing Wuluh: {}
'''.format(len_sirih_train, len_seledri_train, len_pepaya_train, len_pandan_train, len_nangka_train, len_lidahbuaya_train, len_kemangi_train, len_jeruk_train, len_jambubiji_train, len_belimbingwuluh_train))

print('''\n==== Jumlah data validation ====
Panjang data validation Sirih: {}
Panjang data validation Peledri: {}
Panjang data validation Pepaya: {}
Panjang data validation Pandan: {}
Panjang data validation Nangka: {}
Panjang data validation Lidah Buaya: {}
Panjang data validation Kemangi: {}
Panjang data validation Jeruk: {}
Panjang data validation Jambu Biji: {}
Panjang data validation Belimbing Wuluh: {}
'''.format(len_sirih_val, len_seledri_val, len_pepaya_val, len_pandan_val, len_nangka_val, len_lidahbuaya_val, len_kemangi_val, len_jeruk_val, len_jambubiji_val, len_belimbingwuluh_val))
# Out:
# Panjang train: 2590
# Panjang validation: 870
#
# ==== Jumlah data train ====
# Panjang data train Sirih: 259
# Panjang data train Peledri: 259
# Panjang data train Pepaya: 259
# Panjang data train Pandan: 259
# Panjang data train Nangka: 259
# Panjang data train Lidah Buaya: 259
# Panjang data train Kemangi: 259
# Panjang data train Jeruk: 259
# Panjang data train Jambu Biji: 259
# Panjang data train Belimbing Wuluh: 259
#
#
# ==== Jumlah data validation ====
# Panjang data validation Sirih: 87
# Panjang data validation Peledri: 87
# Panjang data validation Pepaya: 87
# Panjang data validation Pandan: 87
# Panjang data validation Nangka: 87
# Panjang data validation Lidah Buaya: 87
# Panjang data validation Kemangi: 87
# Panjang data validation Jeruk: 87
# Panjang data validation Jambu Biji: 87
# Panjang data validation Belimbing Wuluh: 87

# %%
train_sirih_fnames = os.listdir(sirih_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_jambubiji_fnames = os.listdir(jambubiji_train_path)
train_belimbingwuluh_fnames = os.listdir(belimbingwuluh_train_path)

print(train_sirih_fnames[:10])
print(train_seledri_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_pandan_fnames[:10])
print(train_nangka_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_jambubiji_fnames[:10])
print(train_belimbingwuluh_fnames[:10])
# Out:
# ['Sirih10.jpg', 'Sirih100.jpg', 'Sirih102.jpg', 'Sirih104.jpg', 'Sirih105.jpg', 'Sirih106.jpg', 'Sirih107.jpg', 'Sirih108.jpg', 'Sirih109.jpg', 'Sirih11.jpg']
# ['Seledri10.jpg', 'Seledri100.jpg', 'Seledri102.jpg', 'Seledri104.jpg', 'Seledri105.jpg', 'Seledri106.jpg', 'Seledri107.jpg', 'Seledri108.jpg', 'Seledri109.jpg', 'Seledri11.jpg']
# ['Pepaya10.jpg', 'Pepaya100.jpg', 'Pepaya102.jpg', 'Pepaya104.jpg', 'Pepaya105.jpg', 'Pepaya106.jpg', 'Pepaya107.jpg', 'Pepaya108.jpg', 'Pepaya109.jpg', 'Pepaya11.jpg']
# ['Pandan10.jpg', 'Pandan100.jpg', 'Pandan102.jpg', 'Pandan104.jpg', 'Pandan105.jpg', 'Pandan106.jpg', 'Pandan107.jpg', 'Pandan108.jpg', 'Pandan109.jpg', 'Pandan11.jpg']
# ['Nangka10.jpg', 'Nangka100.jpg', 'Nangka102.jpg', 'Nangka104.jpg', 'Nangka105.jpg', 'Nangka106.jpg', 'Nangka107.jpg', 'Nangka108.jpg', 'Nangka109.jpg', 'Nangka11.jpg']
# ['Lidah buaya10.jpg', 'Lidah buaya100.jpg', 'Lidah buaya102.jpg', 'Lidah buaya104.jpg', 'Lidah buaya105.jpg', 'Lidah buaya106.jpg', 'Lidah buaya107.jpg', 'Lidah buaya108.jpg', 'Lidah buaya109.jpg', 'Lidah buaya11.jpg']
# ['Kemangi10.jpg', 'Kemangi100.jpg', 'Kemangi102.jpg', 'Kemangi104.jpg', 'Kemangi105.jpg', 'Kemangi106.jpg', 'Kemangi107.jpg', 'Kemangi108.jpg', 'Kemangi109.jpg', 'Kemangi11.jpg']
# ['Jeruk10.jpg', 'Jeruk100.jpg', 'Jeruk102.jpg', 'Jeruk104.jpg', 'Jeruk105.jpg', 'Jeruk106.jpg', 'Jeruk107.jpg', 'Jeruk108.jpg', 'Jeruk109.jpg', 'Jeruk11.jpg']
# ['Jambu biji10.jpg', 'Jambu biji100.jpg', 'Jambu biji102.jpg', 'Jambu biji104.jpg', 'Jambu biji105.jpg', 'Jambu biji106.jpg', 'Jambu biji107.jpg', 'Jambu biji108.jpg', 'Jambu biji109.jpg', 'Jambu biji11.jpg']
# ['Belimbing Wuluh10.jpg', 'Belimbing Wuluh100.jpg', 'Belimbing Wuluh102.jpg', 'Belimbing Wuluh104.jpg', 'Belimbing Wuluh105.jpg', 'Belimbing Wuluh106.jpg', 'Belimbing Wuluh107.jpg', 'Belimbing Wuluh108.jpg', 'Belimbing Wuluh109.jpg', 'Belimbing Wuluh11.jpg']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 10
ncols = 8

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_sirih_pix = [os.path.join(sirih_train_path, fname)
                  for fname in train_sirih_fnames[ pic_index-8:pic_index]
                 ]
next_seledri_pix = [os.path.join(seledri_train_path, fname)
                  for fname in train_seledri_fnames[ pic_index-8:pic_index]
                 ]
next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
                    for fname in train_pepaya_fnames[ pic_index-8:pic_index]
                  ]
next_pandan_pix = [os.path.join(pandan_train_path, fname)
                    for fname in train_pandan_fnames[ pic_index-8:pic_index]
                  ]
next_nangka_pix = [os.path.join(nangka_train_path, fname)
                    for fname in train_nangka_fnames[ pic_index-8:pic_index]
                  ]
next_lidahbuaya_pix = [os.path.join(lidahbuaya_train_path, fname)
                    for fname in train_lidahbuaya_fnames[ pic_index-8:pic_index]
                  ]
next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
                    for fname in train_kemangi_fnames[ pic_index-8:pic_index]
                  ]
next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
                    for fname in train_jeruk_fnames[ pic_index-8:pic_index]
                  ]
next_jambubiji_pix = [os.path.join(jambubiji_train_path, fname)
                    for fname in train_jambubiji_fnames[ pic_index-8:pic_index]
                  ]
next_belimbingwuluh_pix = [os.path.join(belimbingwuluh_train_path, fname)
                    for fname in train_belimbingwuluh_fnames[ pic_index-8:pic_index]
                  ]

print(next_sirih_pix)
                
for i, img_path in enumerate(next_sirih_pix + next_seledri_pix + next_pepaya_pix + next_pandan_pix + next_nangka_pix + next_lidahbuaya_pix + next_kemangi_pix + next_jeruk_pix + next_jambubiji_pix + next_belimbingwuluh_pix):
  sp =  plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# ['C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih10.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih100.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih102.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih104.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih105.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih106.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih107.jpg', 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted\\train\\Sirih\\Sirih108.jpg']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.3,
    zoom_range = 0.3,
    rotation_range = 30,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest',
)
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle=True,
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)

test_datagen = ImageDataGenerator(
    rescale = 1./255,
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 2590 images belonging to 10 classes.
# Found 870 images belonging to 10 classes.
# Found 40 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout

# %%
image_size=[150,150]
vgg=VGG16(input_shape=image_size+[3], weights='imagenet', include_top=False)
vgg.output
# Out:
# <KerasTensor: shape=(None, 4, 4, 512) dtype=float32 (created by layer 'block5_pool')>

# %%
x=Flatten()(vgg.output)
x=Dense(512, activation='relu')(x)
prediction=Dense(10,activation='softmax')(x)

# %%
model=Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,914,634
# Trainable params: 18,914,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nYour model accuration has been reached: 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=20,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=10,
      verbose=1,
      callbacks = [callbacks],
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 15s 523ms/step - loss: 2.3136 - accuracy: 0.1844 - val_loss: 2.0198 - val_accuracy: 0.2062
# Epoch 2/100
# 20/20 [==============================] - 12s 629ms/step - loss: 1.8138 - accuracy: 0.4182 - val_loss: 1.3058 - val_accuracy: 0.6500
# Epoch 3/100
# 20/20 [==============================] - 11s 536ms/step - loss: 1.2559 - accuracy: 0.6094 - val_loss: 1.0826 - val_accuracy: 0.6875
# Epoch 4/100
# 20/20 [==============================] - 10s 530ms/step - loss: 1.0507 - accuracy: 0.6500 - val_loss: 0.7895 - val_accuracy: 0.7375
# Epoch 5/100
# 20/20 [==============================] - 11s 576ms/step - loss: 0.8475 - accuracy: 0.6969 - val_loss: 1.2341 - val_accuracy: 0.5750
# Epoch 6/100
# 20/20 [==============================] - 11s 550ms/step - loss: 0.7516 - accuracy: 0.7406 - val_loss: 1.0105 - val_accuracy: 0.6687
# Epoch 7/100
# 20/20 [==============================] - 11s 560ms/step - loss: 0.7086 - accuracy: 0.7704 - val_loss: 0.6813 - val_accuracy: 0.7312
# Epoch 8/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.5871 - accuracy: 0.8219 - val_loss: 0.7620 - val_accuracy: 0.6875
# Epoch 9/100
# 20/20 [==============================] - 10s 512ms/step - loss: 0.4300 - accuracy: 0.8438 - val_loss: 0.5318 - val_accuracy: 0.8000
# Epoch 10/100
# 20/20 [==============================] - 11s 531ms/step - loss: 0.4044 - accuracy: 0.8562 - val_loss: 0.3683 - val_accuracy: 0.8687
# Epoch 11/100
# 20/20 [==============================] - 10s 504ms/step - loss: 0.4391 - accuracy: 0.8469 - val_loss: 0.4076 - val_accuracy: 0.8500
# Epoch 12/100
# 20/20 [==============================] - 11s 583ms/step - loss: 0.6461 - accuracy: 0.7719 - val_loss: 0.4447 - val_accuracy: 0.8813
# Epoch 13/100
# 20/20 [==============================] - 10s 505ms/step - loss: 0.3691 - accuracy: 0.8719 - val_loss: 0.2517 - val_accuracy: 0.9125
# Epoch 14/100
# 20/20 [==============================] - 11s 571ms/step - loss: 0.3585 - accuracy: 0.8656 - val_loss: 0.4826 - val_accuracy: 0.8250
# Epoch 15/100
# 20/20 [==============================] - 12s 615ms/step - loss: 0.3179 - accuracy: 0.8875 - val_loss: 0.5012 - val_accuracy: 0.8188
# Epoch 16/100
# 20/20 [==============================] - 10s 506ms/step - loss: 0.3890 - accuracy: 0.8687 - val_loss: 0.3405 - val_accuracy: 0.8750
# Epoch 17/100
# 20/20 [==============================] - 11s 543ms/step - loss: 0.4183 - accuracy: 0.8687 - val_loss: 0.4397 - val_accuracy: 0.8438
# Epoch 18/100
# 20/20 [==============================] - 10s 516ms/step - loss: 0.3657 - accuracy: 0.8553 - val_loss: 0.5882 - val_accuracy: 0.7750
# Epoch 19/100
# 20/20 [==============================] - 10s 501ms/step - loss: 0.3396 - accuracy: 0.9094 - val_loss: 0.2531 - val_accuracy: 0.9125
# Epoch 20/100
# 20/20 [==============================] - 11s 535ms/step - loss: 0.2752 - accuracy: 0.8969 - val_loss: 0.2493 - val_accuracy: 0.9125
# Epoch 21/100
# 20/20 [==============================] - 10s 519ms/step - loss: 0.2809 - accuracy: 0.9031 - val_loss: 0.4589 - val_accuracy: 0.8250
# Epoch 22/100
# 20/20 [==============================] - 12s 595ms/step - loss: 0.2651 - accuracy: 0.9031 - val_loss: 0.5436 - val_accuracy: 0.7875
# Epoch 23/100
# 20/20 [==============================] - 11s 576ms/step - loss: 0.2057 - accuracy: 0.9277 - val_loss: 0.6643 - val_accuracy: 0.7750
# Epoch 24/100
# 20/20 [==============================] - 10s 513ms/step - loss: 0.1782 - accuracy: 0.9531 - val_loss: 0.5160 - val_accuracy: 0.8250
# Epoch 25/100
# 20/20 [==============================] - 11s 537ms/step - loss: 0.2694 - accuracy: 0.9088 - val_loss: 0.3510 - val_accuracy: 0.8625
# Epoch 26/100
# 20/20 [==============================] - 11s 546ms/step - loss: 0.2087 - accuracy: 0.9250 - val_loss: 0.4762 - val_accuracy: 0.8188
# Epoch 27/100
# 20/20 [==============================] - 11s 532ms/step - loss: 0.2120 - accuracy: 0.9375 - val_loss: 0.2964 - val_accuracy: 0.9187
# Epoch 28/100
# 20/20 [==============================] - 11s 566ms/step - loss: 0.2002 - accuracy: 0.9281 - val_loss: 0.4898 - val_accuracy: 0.8313
# Epoch 29/100
# 20/20 [==============================] - 11s 519ms/step - loss: 0.1460 - accuracy: 0.9438 - val_loss: 0.3061 - val_accuracy: 0.9125
# Epoch 30/100
# 20/20 [==============================] - 11s 526ms/step - loss: 0.3253 - accuracy: 0.9031 - val_loss: 0.3910 - val_accuracy: 0.8750
# Epoch 31/100
# 20/20 [==============================] - 11s 557ms/step - loss: 0.2952 - accuracy: 0.8938 - val_loss: 0.4161 - val_accuracy: 0.8687
# Epoch 32/100
# 20/20 [==============================] - 10s 479ms/step - loss: 0.1784 - accuracy: 0.9375 - val_loss: 0.3255 - val_accuracy: 0.9000
# Epoch 33/100
# 20/20 [==============================] - 9s 477ms/step - loss: 0.2639 - accuracy: 0.9281 - val_loss: 0.1765 - val_accuracy: 0.9438
# Epoch 34/100
# 20/20 [==============================] - 12s 578ms/step - loss: 0.1929 - accuracy: 0.9406 - val_loss: 0.6136 - val_accuracy: 0.7875
# Epoch 35/100
# 20/20 [==============================] - 11s 556ms/step - loss: 0.1629 - accuracy: 0.9375 - val_loss: 0.5496 - val_accuracy: 0.8188
# Epoch 36/100
# 20/20 [==============================] - 11s 539ms/step - loss: 0.1993 - accuracy: 0.9250 - val_loss: 0.1681 - val_accuracy: 0.9500
# Epoch 37/100
# 20/20 [==============================] - 10s 490ms/step - loss: 0.1655 - accuracy: 0.9406 - val_loss: 0.2445 - val_accuracy: 0.9125
# Epoch 38/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.1931 - accuracy: 0.9250 - val_loss: 0.0923 - val_accuracy: 0.9688
# Epoch 39/100
# 20/20 [==============================] - 10s 505ms/step - loss: 0.2608 - accuracy: 0.9156 - val_loss: 0.1367 - val_accuracy: 0.9688
# Epoch 40/100
# 20/20 [==============================] - 11s 551ms/step - loss: 0.3272 - accuracy: 0.8969 - val_loss: 0.2333 - val_accuracy: 0.9187
# Epoch 41/100
# 20/20 [==============================] - 11s 545ms/step - loss: 0.1822 - accuracy: 0.9438 - val_loss: 0.3101 - val_accuracy: 0.8938
# Epoch 42/100
# 20/20 [==============================] - 11s 547ms/step - loss: 0.1690 - accuracy: 0.9500 - val_loss: 0.3905 - val_accuracy: 0.8938
# Epoch 43/100
# 20/20 [==============================] - 11s 556ms/step - loss: 0.1508 - accuracy: 0.9563 - val_loss: 0.3589 - val_accuracy: 0.8875
# Epoch 44/100
# 20/20 [==============================] - 12s 574ms/step - loss: 0.1355 - accuracy: 0.9438 - val_loss: 0.1489 - val_accuracy: 0.9563
# Epoch 45/100
# 20/20 [==============================] - 10s 507ms/step - loss: 0.1911 - accuracy: 0.9469 - val_loss: 0.4148 - val_accuracy: 0.8562
# Epoch 46/100
# 20/20 [==============================] - 10s 507ms/step - loss: 0.1616 - accuracy: 0.9438 - val_loss: 0.3593 - val_accuracy: 0.8813
# Epoch 47/100
# 20/20 [==============================] - 11s 528ms/step - loss: 0.1258 - accuracy: 0.9594 - val_loss: 0.1509 - val_accuracy: 0.9438
# Epoch 48/100
# 20/20 [==============================] - 11s 528ms/step - loss: 0.1508 - accuracy: 0.9500 - val_loss: 0.2897 - val_accuracy: 0.9250
# Epoch 49/100
# 20/20 [==============================] - 12s 599ms/step - loss: 0.1403 - accuracy: 0.9469 - val_loss: 0.2530 - val_accuracy: 0.9250
# Epoch 50/100
# 20/20 [==============================] - 11s 551ms/step - loss: 0.1598 - accuracy: 0.9344 - val_loss: 0.1802 - val_accuracy: 0.9563
# Epoch 51/100
# 20/20 [==============================] - 12s 585ms/step - loss: 0.0948 - accuracy: 0.9781 - val_loss: 0.2583 - val_accuracy: 0.9062
# Epoch 52/100
# 20/20 [==============================] - 11s 530ms/step - loss: 0.1002 - accuracy: 0.9654 - val_loss: 0.1973 - val_accuracy: 0.9312
# Epoch 53/100
# 20/20 [==============================] - 11s 551ms/step - loss: 0.1155 - accuracy: 0.9594 - val_loss: 0.5051 - val_accuracy: 0.8250
# Epoch 54/100
# 20/20 [==============================] - 10s 526ms/step - loss: 0.1629 - accuracy: 0.9560 - val_loss: 0.2409 - val_accuracy: 0.9250
# Epoch 55/100
# 20/20 [==============================] - 11s 554ms/step - loss: 0.1268 - accuracy: 0.9563 - val_loss: 0.8757 - val_accuracy: 0.7563
# Epoch 56/100
# 20/20 [==============================] - 11s 535ms/step - loss: 0.1700 - accuracy: 0.9406 - val_loss: 0.2812 - val_accuracy: 0.9187
# Epoch 57/100
# 20/20 [==============================] - 11s 550ms/step - loss: 0.1224 - accuracy: 0.9563 - val_loss: 0.2027 - val_accuracy: 0.9375
# Epoch 58/100
# 20/20 [==============================] - 10s 491ms/step - loss: 0.0986 - accuracy: 0.9719 - val_loss: 0.1292 - val_accuracy: 0.9688
# Epoch 59/100
# 20/20 [==============================] - 12s 587ms/step - loss: 0.1507 - accuracy: 0.9469 - val_loss: 0.1330 - val_accuracy: 0.9500
# Epoch 60/100
# 20/20 [==============================] - 10s 498ms/step - loss: 0.1350 - accuracy: 0.9469 - val_loss: 0.4696 - val_accuracy: 0.8562
# Epoch 61/100
# 20/20 [==============================] - 11s 535ms/step - loss: 0.1408 - accuracy: 0.9625 - val_loss: 0.1804 - val_accuracy: 0.9375
# Epoch 62/100
# 20/20 [==============================] - 10s 505ms/step - loss: 0.1339 - accuracy: 0.9563 - val_loss: 0.1618 - val_accuracy: 0.9500
# Epoch 63/100
# 20/20 [==============================] - 11s 535ms/step - loss: 0.1123 - accuracy: 0.9688 - val_loss: 0.2412 - val_accuracy: 0.9375
# Epoch 64/100
# 20/20 [==============================] - 11s 571ms/step - loss: 0.0860 - accuracy: 0.9717 - val_loss: 0.2290 - val_accuracy: 0.9062
# Epoch 65/100
# 20/20 [==============================] - 11s 548ms/step - loss: 0.1598 - accuracy: 0.9500 - val_loss: 0.0608 - val_accuracy: 0.9875
# Epoch 66/100
# 20/20 [==============================] - 10s 508ms/step - loss: 0.1265 - accuracy: 0.9438 - val_loss: 0.2096 - val_accuracy: 0.9375
# Epoch 67/100
# 20/20 [==============================] - 12s 568ms/step - loss: 0.1173 - accuracy: 0.9688 - val_loss: 0.3037 - val_accuracy: 0.8938
# Epoch 68/100
# 20/20 [==============================] - 10s 499ms/step - loss: 0.1035 - accuracy: 0.9654 - val_loss: 0.2840 - val_accuracy: 0.9187
# Epoch 69/100
# 20/20 [==============================] - 11s 536ms/step - loss: 0.0764 - accuracy: 0.9811 - val_loss: 0.3374 - val_accuracy: 0.8875
# Epoch 70/100
# 20/20 [==============================] - 11s 542ms/step - loss: 0.0905 - accuracy: 0.9812 - val_loss: 0.1557 - val_accuracy: 0.9625
# Epoch 71/100
# 20/20 [==============================] - 11s 522ms/step - loss: 0.0852 - accuracy: 0.9750 - val_loss: 0.2387 - val_accuracy: 0.9250
# Epoch 72/100
# 20/20 [==============================] - 11s 523ms/step - loss: 0.0936 - accuracy: 0.9812 - val_loss: 0.5257 - val_accuracy: 0.8375
# Epoch 73/100
# 20/20 [==============================] - 12s 589ms/step - loss: 0.1040 - accuracy: 0.9750 - val_loss: 0.1566 - val_accuracy: 0.9312
# Epoch 74/100
# 20/20 [==============================] - 11s 529ms/step - loss: 0.0759 - accuracy: 0.9875 - val_loss: 0.1652 - val_accuracy: 0.9187
# Epoch 75/100
# 20/20 [==============================] - 11s 543ms/step - loss: 0.0898 - accuracy: 0.9781 - val_loss: 0.2401 - val_accuracy: 0.9000
# Epoch 76/100
# 20/20 [==============================] - 10s 493ms/step - loss: 0.0847 - accuracy: 0.9780 - val_loss: 0.1085 - val_accuracy: 0.9688
# Epoch 77/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.0762 - accuracy: 0.9688 - val_loss: 0.2000 - val_accuracy: 0.9250
# Epoch 78/100
# 20/20 [==============================] - 10s 476ms/step - loss: 0.0791 - accuracy: 0.9781 - val_loss: 0.1649 - val_accuracy: 0.9250
# Epoch 79/100
# 20/20 [==============================] - 12s 580ms/step - loss: 0.0686 - accuracy: 0.9812 - val_loss: 0.3017 - val_accuracy: 0.8750
# Epoch 80/100
# 20/20 [==============================] - 10s 510ms/step - loss: 0.1144 - accuracy: 0.9594 - val_loss: 0.1682 - val_accuracy: 0.9250
# Epoch 81/100
# 20/20 [==============================] - 10s 521ms/step - loss: 0.1170 - accuracy: 0.9656 - val_loss: 0.1262 - val_accuracy: 0.9438
# Epoch 82/100
# 20/20 [==============================] - 11s 537ms/step - loss: 0.0835 - accuracy: 0.9717 - val_loss: 0.2240 - val_accuracy: 0.9312
# Epoch 83/100
# 20/20 [==============================] - 11s 530ms/step - loss: 0.1178 - accuracy: 0.9591 - val_loss: 0.4163 - val_accuracy: 0.9000
# Epoch 84/100
# 20/20 [==============================] - 10s 492ms/step - loss: 0.0999 - accuracy: 0.9656 - val_loss: 0.0656 - val_accuracy: 0.9750
# Epoch 85/100
# 20/20 [==============================] - 11s 569ms/step - loss: 0.0508 - accuracy: 0.9874 - val_loss: 0.3811 - val_accuracy: 0.8750
# Epoch 86/100
# 20/20 [==============================] - 11s 538ms/step - loss: 0.0941 - accuracy: 0.9717 - val_loss: 0.0834 - val_accuracy: 0.9750
# Epoch 87/100
# 20/20 [==============================] - 11s 540ms/step - loss: 0.0643 - accuracy: 0.9844 - val_loss: 0.3309 - val_accuracy: 0.9000
# Epoch 88/100
# 20/20 [==============================] - 10s 515ms/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.3043 - val_accuracy: 0.8938
# Epoch 89/100
# 20/20 [==============================] - 11s 529ms/step - loss: 0.0533 - accuracy: 0.9875 - val_loss: 0.3246 - val_accuracy: 0.8875
# Epoch 90/100
# 20/20 [==============================] - 11s 561ms/step - loss: 0.0955 - accuracy: 0.9625 - val_loss: 0.3947 - val_accuracy: 0.8938
# Epoch 91/100
# 20/20 [==============================] - 10s 491ms/step - loss: 0.0923 - accuracy: 0.9688 - val_loss: 0.2391 - val_accuracy: 0.9187
# Epoch 92/100
# 20/20 [==============================] - 11s 532ms/step - loss: 0.0793 - accuracy: 0.9811 - val_loss: 0.1205 - val_accuracy: 0.9625
# Epoch 93/100
# 20/20 [==============================] - 11s 543ms/step - loss: 0.0632 - accuracy: 0.9812 - val_loss: 0.4961 - val_accuracy: 0.8375
# Epoch 94/100
# 20/20 [==============================] - 10s 512ms/step - loss: 0.1059 - accuracy: 0.9719 - val_loss: 0.2075 - val_accuracy: 0.9187
# Epoch 95/100
# 20/20 [==============================] - 11s 543ms/step - loss: 0.0677 - accuracy: 0.9812 - val_loss: 0.1956 - val_accuracy: 0.9312
# Epoch 96/100
# 20/20 [==============================] - 11s 525ms/step - loss: 0.0609 - accuracy: 0.9781 - val_loss: 0.1313 - val_accuracy: 0.9625
# Epoch 97/100
# 20/20 [==============================] - 12s 588ms/step - loss: 0.0613 - accuracy: 0.9750 - val_loss: 0.1939 - val_accuracy: 0.9500
# Epoch 98/100
# 20/20 [==============================] - 11s 535ms/step - loss: 0.0681 - accuracy: 0.9812 - val_loss: 0.2008 - val_accuracy: 0.9438
# Epoch 99/100
# 20/20 [==============================] - 11s 563ms/step - loss: 0.0669 - accuracy: 0.9844 - val_loss: 0.1213 - val_accuracy: 0.9688
# Epoch 100/100
# 20/20 [==============================] - 10s 517ms/step - loss: 0.0742 - accuracy: 0.9875 - val_loss: 0.1576 - val_accuracy: 0.9500

# %%
model.save('C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/save_model/fix.h5')

# %%
from keras.models import load_model

model = load_model('C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/save_model/1layer.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training dan Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training dan validation loss')
plt.legend(loc=0)

plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np

sns.set(style='whitegrid')

testLab = test_generator.classes
pred = model.predict(test_generator)
y_pred = np.argmax(pred, axis=-1)
class_names = test_generator.class_indices

print(classification_report(y_pred, testLab, target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
# Belimbing Wuluh       1.00      1.00      1.00         4
#      Jambu biji       1.00      1.00      1.00         4
#           Jeruk       1.00      1.00      1.00         4
#         Kemangi       1.00      1.00      1.00         4
#     Lidah buaya       1.00      1.00      1.00         4
#          Nangka       1.00      1.00      1.00         4
#          Pandan       1.00      1.00      1.00         4
#          Pepaya       1.00      1.00      1.00         4
#         Seledri       1.00      1.00      1.00         4
#           Sirih       1.00      1.00      1.00         4
#
#        accuracy                           1.00        40
#       macro avg       1.00      1.00      1.00        40
#    weighted avg       1.00      1.00      1.00        40

# %%
Cmatrix_test = confusion_matrix(testLab, y_pred)
plt.figure(figsize=(13,10))
ax = plt.subplot()
data = np.asarray(Cmatrix_test).reshape(10,10)
sns.heatmap(data, annot=True, fmt='', ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels', fontsize=14)
ax.set_ylabel('True labels', fontsize=14)
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Report', fontsize=18)
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
# from google.colab import files

path_test = 'C:/Users/USER/Downloads/WAHYU JELEK/Kecerdasan Buatan/splitted/train/Jeruk/Jeruk3.jpg'

# uploaded = files.upload()
 
# for fn in uploaded.keys():
#   path = fn
img = image.load_img(path_test, target_size=(150,150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)

class_list = os.listdir(train_dir)

if classes[0][0]:
    prediction="Belimbing Wuluh"
elif classes[0][1]:
    prediction="Jambu Biji"
elif classes[0][2]:
    prediction="Jeruk"
elif classes[0][3]:
    prediction="Kemangi"
elif classes[0][4]:
    prediction="Lidah Buaya"
elif classes[0][5]:
    prediction="Nangka"
elif classes[0][6]:
    prediction="Pandan"
elif classes[0][7]:
    prediction="Pepaya"
elif classes[0][8]:
    prediction="Seledri"
elif classes[0][9]:
    prediction="Sirih"
else:
    prediction="[Undefined]"
print(prediction)
