# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyubudii/CNN-VGG16-Herbal-Leaf-Classification/blob/main/No_Augmentasi_Final_Daun_Herbal_Wahyu_385_Bella_400.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# %%
# Ekstrak dataset
local_zip = "C:/Users/USER/Downloads/Bella/dataset.zip"
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall("C:/Users/USER/Downloads/Bella")
zip_ref.close()

# %%
base_dir = "C:/Users/USER/Downloads/Bella/dataset_split"

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
classes = ["Sirih","Seledri","Pepaya","Pandan","Nangka","Lidah buaya","Kemangi","Jeruk Nipis","Jambu biji","Belimbing Wuluh"]

sirih_train_path = os.path.join(train_dir, 'Sirih')
seledri_train_path = os.path.join(train_dir, 'Seledri')
pepaya_train_path = os.path.join(train_dir, 'Pepaya')
pandan_train_path = os.path.join(train_dir, 'Pandan')
nangka_train_path = os.path.join(train_dir, 'Nangka')
lidahbuaya_train_path = os.path.join(train_dir, 'Lidah buaya')
kemangi_train_path = os.path.join(train_dir, 'Kemangi')
jeruk_train_path = os.path.join(train_dir, 'Jeruk Nipis')
jambubiji_train_path = os.path.join(train_dir, 'Jambu biji')
belimbingwuluh_train_path = os.path.join(train_dir, 'Belimbing Wuluh')

sirih_val_path = os.path.join(val_dir, 'Sirih')
seledri_val_path = os.path.join(val_dir, 'Seledri')
pepaya_val_path = os.path.join(val_dir, 'Pepaya')
pandan_val_path = os.path.join(val_dir, 'Pandan')
nangka_val_path = os.path.join(val_dir, 'Nangka')
lidahbuaya_val_path = os.path.join(val_dir, 'Lidah buaya')
kemangi_val_path = os.path.join(val_dir, 'Kemangi')
jeruk_val_path = os.path.join(val_dir, 'Jeruk Nipis')
jambubiji_val_path = os.path.join(val_dir, 'Jambu biji')
belimbingwuluh_val_path = os.path.join(val_dir, 'Belimbing Wuluh')

len_sirih_train = len(os.listdir(sirih_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_jambubiji_train = len(os.listdir(jambubiji_train_path))
len_belimbingwuluh_train = len(os.listdir(belimbingwuluh_train_path))

len_sirih_val = len(os.listdir(sirih_val_path))
len_seledri_val = len(os.listdir(seledri_val_path))
len_pepaya_val = len(os.listdir(pepaya_val_path))
len_pandan_val = len(os.listdir(pandan_val_path))
len_nangka_val = len(os.listdir(nangka_val_path))
len_lidahbuaya_val = len(os.listdir(lidahbuaya_val_path))
len_kemangi_val = len(os.listdir(kemangi_val_path))
len_jeruk_val = len(os.listdir(jeruk_val_path))
len_jambubiji_val = len(os.listdir(jambubiji_val_path))
len_belimbingwuluh_val = len(os.listdir(belimbingwuluh_val_path))

print("Panjang train:", str(len_sirih_train + len_seledri_train + len_pepaya_train + len_pandan_train + len_nangka_train + len_lidahbuaya_train + len_kemangi_train + len_jeruk_train + len_jambubiji_train + len_belimbingwuluh_train))
print("Panjang validation:", str(len_sirih_val + len_seledri_val + len_pepaya_val + len_pandan_val + len_nangka_val + len_lidahbuaya_val + len_kemangi_val + len_jeruk_val + len_jambubiji_val + len_belimbingwuluh_val))

print('''\n==== Jumlah data train ====
Panjang data train Sirih: {}
Panjang data train Peledri: {}
Panjang data train Pepaya: {}
Panjang data train Pandan: {}
Panjang data train Nangka: {}
Panjang data train Lidah Buaya: {}
Panjang data train Kemangi: {}
Panjang data train Jeruk: {}
Panjang data train Jambu Biji: {}
Panjang data train Belimbing Wuluh: {}
'''.format(len_sirih_train, len_seledri_train, len_pepaya_train, len_pandan_train, len_nangka_train, len_lidahbuaya_train, len_kemangi_train, len_jeruk_train, len_jambubiji_train, len_belimbingwuluh_train))

print('''\n==== Jumlah data validation ====
Panjang data validation Sirih: {}
Panjang data validation Peledri: {}
Panjang data validation Pepaya: {}
Panjang data validation Pandan: {}
Panjang data validation Nangka: {}
Panjang data validation Lidah Buaya: {}
Panjang data validation Kemangi: {}
Panjang data validation Jeruk: {}
Panjang data validation Jambu Biji: {}
Panjang data validation Belimbing Wuluh: {}
'''.format(len_sirih_val, len_seledri_val, len_pepaya_val, len_pandan_val, len_nangka_val, len_lidahbuaya_val, len_kemangi_val, len_jeruk_val, len_jambubiji_val, len_belimbingwuluh_val))
# Out:
# Panjang train: 2450
# Panjang validation: 700
#
# ==== Jumlah data train ====
# Panjang data train Sirih: 245
# Panjang data train Peledri: 245
# Panjang data train Pepaya: 245
# Panjang data train Pandan: 245
# Panjang data train Nangka: 245
# Panjang data train Lidah Buaya: 245
# Panjang data train Kemangi: 245
# Panjang data train Jeruk: 245
# Panjang data train Jambu Biji: 245
# Panjang data train Belimbing Wuluh: 245
#
#
# ==== Jumlah data validation ====
# Panjang data validation Sirih: 70
# Panjang data validation Peledri: 70
# Panjang data validation Pepaya: 70
# Panjang data validation Pandan: 70
# Panjang data validation Nangka: 70
# Panjang data validation Lidah Buaya: 70
# Panjang data validation Kemangi: 70
# Panjang data validation Jeruk: 70
# Panjang data validation Jambu Biji: 70
# Panjang data validation Belimbing Wuluh: 70

# %%
train_sirih_fnames = os.listdir(sirih_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_jambubiji_fnames = os.listdir(jambubiji_train_path)
train_belimbingwuluh_fnames = os.listdir(belimbingwuluh_train_path)

print(train_sirih_fnames[:10])
print(train_seledri_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_pandan_fnames[:10])
print(train_nangka_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_jambubiji_fnames[:10])
print(train_belimbingwuluh_fnames[:10])
# Out:
# ['Sirih001.jpg', 'Sirih002.jpg', 'Sirih003.jpg', 'Sirih004.jpg', 'Sirih005.jpg', 'Sirih006.jpg', 'Sirih008.jpg', 'Sirih011.jpg', 'Sirih012.jpg', 'Sirih014.jpg']
# ['Seledri001.jpg', 'Seledri002.jpg', 'Seledri003.jpg', 'Seledri004.jpg', 'Seledri005.jpg', 'Seledri006.jpg', 'Seledri008.jpg', 'Seledri011.jpg', 'Seledri012.jpg', 'Seledri014.jpg']
# ['Pepaya001.jpg', 'Pepaya002.jpg', 'Pepaya003.jpg', 'Pepaya004.jpg', 'Pepaya005.jpg', 'Pepaya006.jpg', 'Pepaya008.jpg', 'Pepaya011.jpg', 'Pepaya012.jpg', 'Pepaya014.jpg']
# ['Pandan001.jpg', 'Pandan002.jpg', 'Pandan003.jpg', 'Pandan004.jpg', 'Pandan005.jpg', 'Pandan006.jpg', 'Pandan008.jpg', 'Pandan011.jpg', 'Pandan012.jpg', 'Pandan014.jpg']
# ['Nangka001.jpg', 'Nangka002.jpg', 'Nangka003.jpg', 'Nangka004.jpg', 'Nangka005.jpg', 'Nangka006.jpg', 'Nangka008.jpg', 'Nangka011.jpg', 'Nangka012.jpg', 'Nangka014.jpg']
# ['Lidah Buaya001.jpg', 'Lidah Buaya002.jpg', 'Lidah Buaya003.jpg', 'Lidah Buaya004.jpg', 'Lidah Buaya005.jpg', 'Lidah Buaya006.jpg', 'Lidah Buaya008.jpg', 'Lidah Buaya011.jpg', 'Lidah Buaya012.jpg', 'Lidah Buaya014.jpg']
# ['Kemangi001.jpg', 'Kemangi002.jpg', 'Kemangi003.jpg', 'Kemangi004.jpg', 'Kemangi005.jpg', 'Kemangi006.jpg', 'Kemangi008.jpg', 'Kemangi011.jpg', 'Kemangi012.jpg', 'Kemangi014.jpg']
# ['Jeruk Nipis001.jpg', 'Jeruk Nipis002.jpg', 'Jeruk Nipis003.jpg', 'Jeruk Nipis004.jpg', 'Jeruk Nipis005.jpg', 'Jeruk Nipis006.jpg', 'Jeruk Nipis008.jpg', 'Jeruk Nipis011.jpg', 'Jeruk Nipis012.jpg', 'Jeruk Nipis014.jpg']
# ['Jambu Biji001.jpg', 'Jambu Biji002.jpg', 'Jambu Biji003.jpg', 'Jambu Biji004.jpg', 'Jambu Biji005.jpg', 'Jambu Biji006.jpg', 'Jambu Biji008.jpg', 'Jambu Biji011.jpg', 'Jambu Biji012.jpg', 'Jambu Biji014.jpg']
# ['Belimbing Wuluh001.jpg', 'Belimbing Wuluh002.jpg', 'Belimbing Wuluh003.jpg', 'Belimbing Wuluh004.jpg', 'Belimbing Wuluh005.jpg', 'Belimbing Wuluh006.jpg', 'Belimbing Wuluh008.jpg', 'Belimbing Wuluh011.jpg', 'Belimbing Wuluh012.jpg', 'Belimbing Wuluh014.jpg']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 10
ncols = 8

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_sirih_pix = [os.path.join(sirih_train_path, fname)
                  for fname in train_sirih_fnames[ pic_index-8:pic_index]
                 ]
next_seledri_pix = [os.path.join(seledri_train_path, fname)
                  for fname in train_seledri_fnames[ pic_index-8:pic_index]
                 ]
next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
                    for fname in train_pepaya_fnames[ pic_index-8:pic_index]
                  ]
next_pandan_pix = [os.path.join(pandan_train_path, fname)
                    for fname in train_pandan_fnames[ pic_index-8:pic_index]
                  ]
next_nangka_pix = [os.path.join(nangka_train_path, fname)
                    for fname in train_nangka_fnames[ pic_index-8:pic_index]
                  ]
next_lidahbuaya_pix = [os.path.join(lidahbuaya_train_path, fname)
                    for fname in train_lidahbuaya_fnames[ pic_index-8:pic_index]
                  ]
next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
                    for fname in train_kemangi_fnames[ pic_index-8:pic_index]
                  ]
next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
                    for fname in train_jeruk_fnames[ pic_index-8:pic_index]
                  ]
next_jambubiji_pix = [os.path.join(jambubiji_train_path, fname)
                    for fname in train_jambubiji_fnames[ pic_index-8:pic_index]
                  ]
next_belimbingwuluh_pix = [os.path.join(belimbingwuluh_train_path, fname)
                    for fname in train_belimbingwuluh_fnames[ pic_index-8:pic_index]
                  ]

print(next_sirih_pix)
                
for i, img_path in enumerate(next_sirih_pix + next_seledri_pix + next_pepaya_pix + next_pandan_pix + next_nangka_pix + next_lidahbuaya_pix + next_kemangi_pix + next_jeruk_pix + next_jambubiji_pix + next_belimbingwuluh_pix):
  sp =  plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# ['C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih001.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih002.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih003.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih004.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih005.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih006.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih008.jpg', 'C:/Users/USER/Downloads/Bella/dataset_split\\train\\Sirih\\Sirih011.jpg']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle=True,
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 2450 images belonging to 10 classes.
# Found 700 images belonging to 10 classes.
# Found 350 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout

# %%
image_size=[150,150]
vgg=VGG16(input_shape=image_size+[3], weights='imagenet', include_top=False)
vgg.output
# Out:
# <KerasTensor: shape=(None, 4, 4, 512) dtype=float32 (created by layer 'block5_pool')>

# %%
x=Flatten()(vgg.output)
x=Dense(512, activation='relu')(x)
prediction=Dense(10,activation='softmax')(x)

# %%
model=Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 512)               4194816
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,914,634
# Trainable params: 18,914,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nYour model accuration has been reached: 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=20,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=10,
      verbose=1,
      callbacks = [callbacks],
)
# Out:
# Epoch 1/100
#  6/20 [========>.....................] - ETA: 1s - loss: 7.4174 - accuracy: 0.1354WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0438s vs `on_train_batch_end` time: 0.0478s). Check your callbacks.
# 20/20 [==============================] - 8s 181ms/step - loss: 3.7542 - accuracy: 0.2094 - val_loss: 2.4052 - val_accuracy: 0.1063
# Epoch 2/100
# 20/20 [==============================] - 3s 150ms/step - loss: 1.5980 - accuracy: 0.4500 - val_loss: 0.9679 - val_accuracy: 0.7188
# Epoch 3/100
# 20/20 [==============================] - 4s 209ms/step - loss: 1.1608 - accuracy: 0.5850 - val_loss: 0.7677 - val_accuracy: 0.6625
# Epoch 4/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.8630 - accuracy: 0.6719 - val_loss: 0.9144 - val_accuracy: 0.7125
# Epoch 5/100
# 20/20 [==============================] - 3s 142ms/step - loss: 0.6473 - accuracy: 0.7750 - val_loss: 0.6601 - val_accuracy: 0.7688
# Epoch 6/100
# 20/20 [==============================] - 3s 143ms/step - loss: 0.6988 - accuracy: 0.7688 - val_loss: 0.8496 - val_accuracy: 0.7563
# Epoch 7/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.5379 - accuracy: 0.8094 - val_loss: 0.5861 - val_accuracy: 0.7563
# Epoch 8/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.4295 - accuracy: 0.8531 - val_loss: 0.1753 - val_accuracy: 0.9438
# Epoch 9/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3493 - accuracy: 0.8938 - val_loss: 0.2406 - val_accuracy: 0.9125
# Epoch 10/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.2149 - accuracy: 0.9500 - val_loss: 0.1481 - val_accuracy: 0.9500
# Epoch 11/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.3061 - accuracy: 0.9094 - val_loss: 0.1614 - val_accuracy: 0.9438
# Epoch 12/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.2304 - accuracy: 0.9248 - val_loss: 0.1421 - val_accuracy: 0.9438
# Epoch 13/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1575 - accuracy: 0.9500 - val_loss: 0.1200 - val_accuracy: 0.9438
# Epoch 14/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.2324 - accuracy: 0.9344 - val_loss: 0.1333 - val_accuracy: 0.9438
# Epoch 15/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.1865 - accuracy: 0.9438 - val_loss: 0.1276 - val_accuracy: 0.9688
# Epoch 16/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1177 - accuracy: 0.9469 - val_loss: 0.0889 - val_accuracy: 0.9625
# Epoch 17/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.1049 - accuracy: 0.9625 - val_loss: 0.2893 - val_accuracy: 0.9187
# Epoch 18/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.0898 - accuracy: 0.9688 - val_loss: 0.1445 - val_accuracy: 0.9438
# Epoch 19/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.0896 - accuracy: 0.9719 - val_loss: 0.3087 - val_accuracy: 0.8938
# Epoch 20/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1258 - accuracy: 0.9531 - val_loss: 1.8124 - val_accuracy: 0.5625
# Epoch 21/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.2145 - accuracy: 0.9438 - val_loss: 0.2347 - val_accuracy: 0.9375
# Epoch 22/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1300 - accuracy: 0.9719 - val_loss: 0.2243 - val_accuracy: 0.9312
# Epoch 23/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1289 - accuracy: 0.9531 - val_loss: 0.0660 - val_accuracy: 0.9688
# Epoch 24/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.8137 - accuracy: 0.8105 - val_loss: 0.9543 - val_accuracy: 0.6875
# Epoch 25/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.4767 - accuracy: 0.8375 - val_loss: 0.5596 - val_accuracy: 0.8313
# Epoch 26/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.3769 - accuracy: 0.8781 - val_loss: 0.3826 - val_accuracy: 0.8562
# Epoch 27/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.3856 - accuracy: 0.8889 - val_loss: 0.4252 - val_accuracy: 0.8313
# Epoch 28/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1851 - accuracy: 0.9406 - val_loss: 0.2607 - val_accuracy: 0.9062
# Epoch 29/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1673 - accuracy: 0.9563 - val_loss: 0.6766 - val_accuracy: 0.7563
# Epoch 30/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.2084 - accuracy: 0.9219 - val_loss: 0.2165 - val_accuracy: 0.9250
# Epoch 31/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.2161 - accuracy: 0.9281 - val_loss: 0.1255 - val_accuracy: 0.9500
# Epoch 32/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.1156 - accuracy: 0.9563 - val_loss: 0.1620 - val_accuracy: 0.9312
# Epoch 33/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.0968 - accuracy: 0.9719 - val_loss: 0.2531 - val_accuracy: 0.9125
# Epoch 34/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.0952 - accuracy: 0.9719 - val_loss: 0.1047 - val_accuracy: 0.9812
# Epoch 35/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.0779 - accuracy: 0.9781 - val_loss: 0.2421 - val_accuracy: 0.9062
# Epoch 36/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.0672 - accuracy: 0.9812 - val_loss: 0.1296 - val_accuracy: 0.9563
# Epoch 37/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9906
# Your model accuration has been reached: 99%
# 20/20 [==============================] - 3s 134ms/step - loss: 0.0393 - accuracy: 0.9906 - val_loss: 0.1183 - val_accuracy: 0.9750

# %%
model.save('C:/Users/USER/Downloads/Bella/NoAugmentasi_Model.h5')

# %%
from keras.models import load_model

model = load_model('C:/Users/USER/Downloads/Bella/NoAugmentasi_Model.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training dan Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training dan validation loss')
plt.legend(loc=0)

plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np

sns.set(style='whitegrid')

testLab = test_generator.classes
pred = model.predict(test_generator)
y_pred = np.argmax(pred, axis=-1)
class_names = test_generator.class_indices

print(classification_report(y_pred, testLab, target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
# Belimbing Wuluh       1.00      0.85      0.92        41
#      Jambu Biji       1.00      0.97      0.99        36
#     Jeruk Nipis       0.89      1.00      0.94        31
#         Kemangi       0.97      0.92      0.94        37
#     Lidah Buaya       1.00      0.97      0.99        36
#          Nangka       0.94      0.97      0.96        34
#          Pandan       0.97      1.00      0.99        34
#          Pepaya       0.94      1.00      0.97        33
#         Seledri       1.00      0.97      0.99        36
#           Sirih       0.91      1.00      0.96        32
#
#        accuracy                           0.96       350
#       macro avg       0.96      0.97      0.96       350
#    weighted avg       0.97      0.96      0.96       350

# %%
Cmatrix_test = confusion_matrix(testLab, y_pred)
plt.figure(figsize=(13,10))
ax = plt.subplot()
data = np.asarray(Cmatrix_test).reshape(10,10)
sns.heatmap(data, annot=True, fmt='', ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels', fontsize=14)
ax.set_ylabel('True labels', fontsize=14)
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Report', fontsize=18)
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

path_test = 'C:/Users/USER/Downloads/Bella/dataset_split/test/Belimbing Wuluh/Belimbing Wuluh010.jpg'

# uploaded = files.upload()
 
# for fn in uploaded.keys():
#   path = fn
img = image.load_img(path_test, target_size=(150,150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)

class_list = os.listdir(train_dir)

if classes[0][0]:
    prediction="Belimbing Wuluh"
elif classes[0][1]:
    prediction="Jambu Biji"
elif classes[0][2]:
    prediction="Jeruk"
elif classes[0][3]:
    prediction="Kemangi"
elif classes[0][4]:
    prediction="Lidah Buaya"
elif classes[0][5]:
    prediction="Nangka"
elif classes[0][6]:
    prediction="Pandan"
elif classes[0][7]:
    prediction="Pepaya"
elif classes[0][8]:
    prediction="Seledri"
elif classes[0][9]:
    prediction="Sirih"
else:
    prediction="[Undefined]"
print(prediction)
# Out:
# Belimbing Wuluh

# %% [markdown]
# DIVIDE

# %%
# Visualisasi Data
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# Augmentasi Data
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Built Model
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout

# Save and Load Model History
from keras.models import load_model

# Model Evaluation and Testing
from sklearn.metrics import classification_report, precision_score, confusion_matrix

# Preprocessing Image
import numpy as np
from keras.preprocessing import image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import shutil
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/Daun Herbal
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Daun Herbal

# %%
# !unzip \*.zip &> /dev/null && rm *.zip

# %%
# !mkdir "/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split"

# %%
import splitfolders

splitfolders.ratio("/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/s82j8dh4rr-1",
                   output="/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split",
                   seed=1337,
                   ratio=(.7, .2, .1),
                   group_prefix=None)
# Out:
# Copying files: 3500 files [01:45, 33.31 files/s]

# %%
base_dir = "/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split"

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
classes = ["Sirih","Seledri","Pepaya","Pandan","Nangka","Lidah buaya","Kemangi","Jeruk Nipis","Jambu biji","Belimbing Wuluh"]

sirih_train_path = os.path.join(train_dir, 'Sirih')
seledri_train_path = os.path.join(train_dir, 'Seledri')
pepaya_train_path = os.path.join(train_dir, 'Pepaya')
pandan_train_path = os.path.join(train_dir, 'Pandan')
nangka_train_path = os.path.join(train_dir, 'Nangka')
lidahbuaya_train_path = os.path.join(train_dir, 'Lidah Buaya')
kemangi_train_path = os.path.join(train_dir, 'Kemangi')
jeruk_train_path = os.path.join(train_dir, 'Jeruk Nipis')
jambubiji_train_path = os.path.join(train_dir, 'Jambu Biji')
belimbingwuluh_train_path = os.path.join(train_dir, 'Belimbing Wuluh')

sirih_val_path = os.path.join(val_dir, 'Sirih')
seledri_val_path = os.path.join(val_dir, 'Seledri')
pepaya_val_path = os.path.join(val_dir, 'Pepaya')
pandan_val_path = os.path.join(val_dir, 'Pandan')
nangka_val_path = os.path.join(val_dir, 'Nangka')
lidahbuaya_val_path = os.path.join(val_dir, 'Lidah Buaya')
kemangi_val_path = os.path.join(val_dir, 'Kemangi')
jeruk_val_path = os.path.join(val_dir, 'Jeruk Nipis')
jambubiji_val_path = os.path.join(val_dir, 'Jambu Biji')
belimbingwuluh_val_path = os.path.join(val_dir, 'Belimbing Wuluh')

len_sirih_train = len(os.listdir(sirih_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_jambubiji_train = len(os.listdir(jambubiji_train_path))
len_belimbingwuluh_train = len(os.listdir(belimbingwuluh_train_path))

len_sirih_val = len(os.listdir(sirih_val_path))
len_seledri_val = len(os.listdir(seledri_val_path))
len_pepaya_val = len(os.listdir(pepaya_val_path))
len_pandan_val = len(os.listdir(pandan_val_path))
len_nangka_val = len(os.listdir(nangka_val_path))
len_lidahbuaya_val = len(os.listdir(lidahbuaya_val_path))
len_kemangi_val = len(os.listdir(kemangi_val_path))
len_jeruk_val = len(os.listdir(jeruk_val_path))
len_jambubiji_val = len(os.listdir(jambubiji_val_path))
len_belimbingwuluh_val = len(os.listdir(belimbingwuluh_val_path))

print("Panjang train:", str(len_sirih_train + len_seledri_train + len_pepaya_train + len_pandan_train + len_nangka_train + len_lidahbuaya_train + len_kemangi_train + len_jeruk_train + len_jambubiji_train + len_belimbingwuluh_train))
print("Panjang validation:", str(len_sirih_val + len_seledri_val + len_pepaya_val + len_pandan_val + len_nangka_val + len_lidahbuaya_val + len_kemangi_val + len_jeruk_val + len_jambubiji_val + len_belimbingwuluh_val))

print('''\n==== Jumlah data train ====
Panjang data train Sirih: {}
Panjang data train Peledri: {}
Panjang data train Pepaya: {}
Panjang data train Pandan: {}
Panjang data train Nangka: {}
Panjang data train Lidah Buaya: {}
Panjang data train Kemangi: {}
Panjang data train Jeruk: {}
Panjang data train Jambu Biji: {}
Panjang data train Belimbing Wuluh: {}
'''.format(len_sirih_train, len_seledri_train, len_pepaya_train, len_pandan_train, len_nangka_train, len_lidahbuaya_train, len_kemangi_train, len_jeruk_train, len_jambubiji_train, len_belimbingwuluh_train))

print('''\n==== Jumlah data validation ====
Panjang data validation Sirih: {}
Panjang data validation Peledri: {}
Panjang data validation Pepaya: {}
Panjang data validation Pandan: {}
Panjang data validation Nangka: {}
Panjang data validation Lidah Buaya: {}
Panjang data validation Kemangi: {}
Panjang data validation Jeruk: {}
Panjang data validation Jambu Biji: {}
Panjang data validation Belimbing Wuluh: {}
'''.format(len_sirih_val, len_seledri_val, len_pepaya_val, len_pandan_val, len_nangka_val, len_lidahbuaya_val, len_kemangi_val, len_jeruk_val, len_jambubiji_val, len_belimbingwuluh_val))
# Out:
# Panjang train: 2440
# Panjang validation: 700
#
# ==== Jumlah data train ====
# Panjang data train Sirih: 244
# Panjang data train Peledri: 244
# Panjang data train Pepaya: 244
# Panjang data train Pandan: 244
# Panjang data train Nangka: 244
# Panjang data train Lidah Buaya: 244
# Panjang data train Kemangi: 244
# Panjang data train Jeruk: 244
# Panjang data train Jambu Biji: 244
# Panjang data train Belimbing Wuluh: 244
#
#
# ==== Jumlah data validation ====
# Panjang data validation Sirih: 70
# Panjang data validation Peledri: 70
# Panjang data validation Pepaya: 70
# Panjang data validation Pandan: 70
# Panjang data validation Nangka: 70
# Panjang data validation Lidah Buaya: 70
# Panjang data validation Kemangi: 70
# Panjang data validation Jeruk: 70
# Panjang data validation Jambu Biji: 70
# Panjang data validation Belimbing Wuluh: 70

# %%
train_sirih_fnames = os.listdir(sirih_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_jambubiji_fnames = os.listdir(jambubiji_train_path)
train_belimbingwuluh_fnames = os.listdir(belimbingwuluh_train_path)

print(train_sirih_fnames[:10])
print(train_seledri_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_pandan_fnames[:10])
print(train_nangka_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_jambubiji_fnames[:10])
print(train_belimbingwuluh_fnames[:10])
# Out:
# ['Sirih129.jpg', 'Sirih193.jpg', 'Sirih346.jpg', 'Sirih231.jpg', 'Sirih016.jpg', 'Sirih133.jpg', 'Sirih321.jpg', 'Sirih294.jpg', 'Sirih286.jpg', 'Sirih138.jpg']
# ['Seledri129.jpg', 'Seledri193.jpg', 'Seledri346.jpg', 'Seledri231.jpg', 'Seledri016.jpg', 'Seledri133.jpg', 'Seledri321.jpg', 'Seledri294.jpg', 'Seledri286.jpg', 'Seledri138.jpg']
# ['Pepaya129.jpg', 'Pepaya193.jpg', 'Pepaya346.jpg', 'Pepaya231.jpg', 'Pepaya016.jpg', 'Pepaya133.jpg', 'Pepaya321.jpg', 'Pepaya294.jpg', 'Pepaya286.jpg', 'Pepaya138.jpg']
# ['Pandan129.jpg', 'Pandan193.jpg', 'Pandan346.jpg', 'Pandan231.jpg', 'Pandan016.jpg', 'Pandan133.jpg', 'Pandan321.jpg', 'Pandan294.jpg', 'Pandan286.jpg', 'Pandan138.jpg']
# ['Nangka129.jpg', 'Nangka193.jpg', 'Nangka346.jpg', 'Nangka231.jpg', 'Nangka016.jpg', 'Nangka133.jpg', 'Nangka321.jpg', 'Nangka294.jpg', 'Nangka286.jpg', 'Nangka138.jpg']
# ['Lidah buaya129.jpg', 'Lidah buaya193.jpg', 'Lidah buaya346.jpg', 'Lidah buaya231.jpg', 'Lidah Buaya016.jpg', 'Lidah buaya133.jpg', 'Lidah buaya321.jpg', 'Lidah buaya294.jpg', 'Lidah buaya286.jpg', 'Lidah buaya138.jpg']
# ['Kemangi129.jpg', 'Kemangi193.jpg', 'Kemangi346.jpg', 'Kemangi231.jpg', 'Kemangi016.jpg', 'Kemangi133.jpg', 'Kemangi321.jpg', 'Kemangi294.jpg', 'Kemangi286.jpg', 'Kemangi138.jpg']
# ['Jeruk Nipis129.jpg', 'Jeruk Nipis193.jpg', 'Jeruk Nipis346.jpg', 'Jeruk Nipis231.jpg', 'Jeruk Nipis016.jpg', 'Jeruk Nipis133.jpg', 'Jeruk Nipis321.jpg', 'Jeruk Nipis294.jpg', 'Jeruk Nipis286.jpg', 'Jeruk Nipis138.jpg']
# ['Jambu biji129.jpg', 'Jambu biji193.jpg', 'Jambu biji346.jpg', 'Jambu biji231.jpg', 'Jambu Biji016.jpg', 'Jambu biji133.jpg', 'Jambu biji321.jpg', 'Jambu biji294.jpg', 'Jambu biji286.jpg', 'Jambu biji138.jpg']
# ['Belimbing Wuluh129.jpg', 'Belimbing Wuluh193.jpg', 'Belimbing Wuluh346.jpg', 'Belimbing Wuluh231.jpg', 'Belimbing Wuluh016.jpg', 'Belimbing Wuluh133.jpg', 'Belimbing Wuluh321.jpg', 'Belimbing Wuluh294.jpg', 'Belimbing Wuluh286.jpg', 'Belimbing Wuluh138.jpg']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 10
ncols = 8

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_sirih_pix = [os.path.join(sirih_train_path, fname)
                  for fname in train_sirih_fnames[ pic_index-8:pic_index]
                 ]
next_seledri_pix = [os.path.join(seledri_train_path, fname)
                  for fname in train_seledri_fnames[ pic_index-8:pic_index]
                 ]
next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
                    for fname in train_pepaya_fnames[ pic_index-8:pic_index]
                  ]
next_pandan_pix = [os.path.join(pandan_train_path, fname)
                    for fname in train_pandan_fnames[ pic_index-8:pic_index]
                  ]
next_nangka_pix = [os.path.join(nangka_train_path, fname)
                    for fname in train_nangka_fnames[ pic_index-8:pic_index]
                  ]
next_lidahbuaya_pix = [os.path.join(lidahbuaya_train_path, fname)
                    for fname in train_lidahbuaya_fnames[ pic_index-8:pic_index]
                  ]
next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
                    for fname in train_kemangi_fnames[ pic_index-8:pic_index]
                  ]
next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
                    for fname in train_jeruk_fnames[ pic_index-8:pic_index]
                  ]
next_jambubiji_pix = [os.path.join(jambubiji_train_path, fname)
                    for fname in train_jambubiji_fnames[ pic_index-8:pic_index]
                  ]
next_belimbingwuluh_pix = [os.path.join(belimbingwuluh_train_path, fname)
                    for fname in train_belimbingwuluh_fnames[ pic_index-8:pic_index]
                  ]

print(next_sirih_pix)
                
for i, img_path in enumerate(next_sirih_pix + next_seledri_pix + next_pepaya_pix + next_pandan_pix + next_nangka_pix + next_lidahbuaya_pix + next_kemangi_pix + next_jeruk_pix + next_jambubiji_pix + next_belimbingwuluh_pix):
  sp =  plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# ['/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih129.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih193.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih346.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih231.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih016.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih133.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih321.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/train/Sirih/Sirih294.jpg']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle=True,
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 2440 images belonging to 10 classes.
# Found 700 images belonging to 10 classes.
# Found 360 images belonging to 10 classes.

# %%
image_size=[150,150]
vgg=VGG16(input_shape=image_size+[3], weights='imagenet', include_top=False)
vgg.output
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# <KerasTensor: shape=(None, 4, 4, 512) dtype=float32 (created by layer 'block5_pool')>

# %%
x=Flatten()(vgg.output)
x=Dense(512, activation='relu')(x)
prediction=Dense(10,activation='softmax')(x)

# %%
model=Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,914,634
# Trainable params: 18,914,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nYour model accuration has been reached: 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=20,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=10,
      verbose=1,
      callbacks = [callbacks],
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 299s 15s/step - loss: 2.3353 - accuracy: 0.1531 - val_loss: 2.0371 - val_accuracy: 0.2250
# Epoch 2/100
# 20/20 [==============================] - 287s 14s/step - loss: 1.8171 - accuracy: 0.4135 - val_loss: 1.8591 - val_accuracy: 0.2812
# Epoch 3/100
# 20/20 [==============================] - 326s 16s/step - loss: 1.1493 - accuracy: 0.6531 - val_loss: 0.9442 - val_accuracy: 0.7375
# Epoch 4/100
# 20/20 [==============================] - 291s 15s/step - loss: 0.7464 - accuracy: 0.7344 - val_loss: 0.5218 - val_accuracy: 0.8000
# Epoch 5/100
# 20/20 [==============================] - 294s 15s/step - loss: 0.6720 - accuracy: 0.7750 - val_loss: 0.6426 - val_accuracy: 0.8125
# Epoch 6/100
# 20/20 [==============================] - 292s 15s/step - loss: 0.4624 - accuracy: 0.8438 - val_loss: 0.4578 - val_accuracy: 0.8500
# Epoch 7/100
# 20/20 [==============================] - 284s 14s/step - loss: 0.3257 - accuracy: 0.8942 - val_loss: 0.2997 - val_accuracy: 0.9125
# Epoch 8/100
# 20/20 [==============================] - 291s 15s/step - loss: 0.2818 - accuracy: 0.9000 - val_loss: 0.2285 - val_accuracy: 0.9187
# Epoch 9/100
# 20/20 [==============================] - 292s 15s/step - loss: 0.2778 - accuracy: 0.9156 - val_loss: 0.3469 - val_accuracy: 0.8938
# Epoch 10/100
# 20/20 [==============================] - 290s 15s/step - loss: 0.2248 - accuracy: 0.9250 - val_loss: 0.1423 - val_accuracy: 0.9500
# Epoch 11/100
# 20/20 [==============================] - 288s 14s/step - loss: 0.1693 - accuracy: 0.9455 - val_loss: 0.3147 - val_accuracy: 0.9062
# Epoch 12/100
# 20/20 [==============================] - 291s 15s/step - loss: 0.1612 - accuracy: 0.9625 - val_loss: 0.3084 - val_accuracy: 0.9000
# Epoch 13/100
# 20/20 [==============================] - 293s 15s/step - loss: 0.1615 - accuracy: 0.9563 - val_loss: 0.1198 - val_accuracy: 0.9625
# Epoch 14/100
# 20/20 [==============================] - 293s 15s/step - loss: 0.2381 - accuracy: 0.9250 - val_loss: 0.1514 - val_accuracy: 0.9688
# Epoch 15/100
# 20/20 [==============================] - 282s 14s/step - loss: 0.2254 - accuracy: 0.9391 - val_loss: 0.1027 - val_accuracy: 0.9688
# Epoch 16/100
# 20/20 [==============================] - 279s 14s/step - loss: 0.1272 - accuracy: 0.9615 - val_loss: 0.2186 - val_accuracy: 0.9125
# Epoch 17/100
# 20/20 [==============================] - 288s 14s/step - loss: 0.0931 - accuracy: 0.9750 - val_loss: 0.1695 - val_accuracy: 0.9375
# Epoch 18/100
# 20/20 [==============================] - 292s 15s/step - loss: 0.0776 - accuracy: 0.9812 - val_loss: 0.1194 - val_accuracy: 0.9750
# Epoch 19/100
# 20/20 [==============================] - 290s 15s/step - loss: 0.0880 - accuracy: 0.9750 - val_loss: 0.1452 - val_accuracy: 0.9625
# Epoch 20/100
# 20/20 [==============================] - 292s 15s/step - loss: 0.0820 - accuracy: 0.9656 - val_loss: 0.0998 - val_accuracy: 0.9563
# Epoch 21/100
# 20/20 [==============================] - 286s 14s/step - loss: 0.0902 - accuracy: 0.9744 - val_loss: 0.1426 - val_accuracy: 0.9438
# Epoch 22/100
# 20/20 [==============================] - 287s 14s/step - loss: 0.0813 - accuracy: 0.9679 - val_loss: 0.1964 - val_accuracy: 0.9375
# Epoch 23/100
# 20/20 [==============================] - 290s 15s/step - loss: 0.0575 - accuracy: 0.9781 - val_loss: 0.1020 - val_accuracy: 0.9625
# Epoch 24/100
# 20/20 [==============================] - 291s 15s/step - loss: 0.0440 - accuracy: 0.9875 - val_loss: 0.1306 - val_accuracy: 0.9625
# Epoch 25/100
# 20/20 [==============================] - 292s 15s/step - loss: 0.0527 - accuracy: 0.9875 - val_loss: 0.1922 - val_accuracy: 0.9625
# Epoch 26/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9937
# Your model accuration has been reached: 99%
# 20/20 [==============================] - 290s 15s/step - loss: 0.0295 - accuracy: 0.9937 - val_loss: 0.1195 - val_accuracy: 0.9625

# %%
# !mkdir "/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/Load Model"
model.save('/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/Load Model/NoAugmentasi_Model.h5')

# %%
from keras.models import load_model

model = load_model('/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/Load Model/NoAugmentasi_Model.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training dan Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training dan validation loss')
plt.legend(loc=0)

plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np

sns.set(style='whitegrid')

testLab = test_generator.classes
pred = model.predict(test_generator)
y_pred = np.argmax(pred, axis=-1)
class_names = test_generator.class_indices

print(classification_report(y_pred, testLab, target_names=class_names))
# Out:
# 23/23 [==============================] - 80s 3s/step
#                  precision    recall  f1-score   support
#
# Belimbing Wuluh       0.94      0.94      0.94        36
#      Jambu Biji       1.00      0.97      0.99        37
#     Jeruk Nipis       0.94      0.87      0.91        39
#         Kemangi       0.94      1.00      0.97        34
#     Lidah Buaya       0.97      1.00      0.99        35
#          Nangka       0.94      0.94      0.94        36
#          Pandan       1.00      0.97      0.99        37
#          Pepaya       0.94      1.00      0.97        34
#         Seledri       0.97      0.92      0.95        38
#           Sirih       0.94      1.00      0.97        34
#
#        accuracy                           0.96       360
#       macro avg       0.96      0.96      0.96       360
#    weighted avg       0.96      0.96      0.96       360

# %%
Cmatrix_test = confusion_matrix(testLab, y_pred)
plt.figure(figsize=(13,10))
ax = plt.subplot()
data = np.asarray(Cmatrix_test).reshape(10,10)
sns.heatmap(data, annot=True, fmt='', ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels', fontsize=14)
ax.set_ylabel('True labels', fontsize=14)
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Report', fontsize=18)
plt.show()

# %%
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array
from google.colab import files

path_test = '/content/gdrive/MyDrive/Colab Notebooks/Daun Herbal/dataset_split/test/Pepaya/Pepaya328.jpg'

# uploaded = files.upload()
 
# for fn in uploaded.keys():
#   path = fn
img = image.load_img(path_test, target_size=(150,150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)

class_list = os.listdir(train_dir)

if classes[0][0]:
    prediction="Belimbing Wuluh"
elif classes[0][1]:
    prediction="Jambu Biji"
elif classes[0][2]:
    prediction="Jeruk"
elif classes[0][3]:
    prediction="Kemangi"
elif classes[0][4]:
    prediction="Lidah Buaya"
elif classes[0][5]:
    prediction="Nangka"
elif classes[0][6]:
    prediction="Pandan"
elif classes[0][7]:
    prediction="Pepaya"
elif classes[0][8]:
    prediction="Seledri"
elif classes[0][9]:
    prediction="Sirih"
else:
    prediction="[Undefined]"
print(prediction)
# Out:
# 1/1 [==============================] - 0s 398ms/step
# Pepaya
