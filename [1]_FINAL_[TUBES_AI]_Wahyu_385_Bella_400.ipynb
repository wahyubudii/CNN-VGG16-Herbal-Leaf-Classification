# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyubudii/Leaf-Classification-Using-CNN/blob/main/%5B1%5D_FINAL_%5BTUBES_AI%5D_Wahyu_385_Bella_400.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan

# %%
# !unzip \dataset.zip

# %%
import os

base_dir = "/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
classes = ["Sirih","Seledri","Pepaya","Pandan","Nangka","Lidah buaya","Kemangi","Jeruk","Jambu biji","Belimbing Wuluh"]

sirih_train_path = os.path.join(train_dir, 'Sirih')
seledri_train_path = os.path.join(train_dir, 'Seledri')
pepaya_train_path = os.path.join(train_dir, 'Pepaya')
pandan_train_path = os.path.join(train_dir, 'Pandan')
nangka_train_path = os.path.join(train_dir, 'Nangka')
lidahbuaya_train_path = os.path.join(train_dir, 'Lidah buaya')
kemangi_train_path = os.path.join(train_dir, 'Kemangi')
jeruk_train_path = os.path.join(train_dir, 'Jeruk')
jambubiji_train_path = os.path.join(train_dir, 'Jambu biji')
belimbingwuluh_train_path = os.path.join(train_dir, 'Belimbing Wuluh')

sirih_val_path = os.path.join(val_dir, 'Sirih')
seledri_val_path = os.path.join(val_dir, 'Seledri')
pepaya_val_path = os.path.join(val_dir, 'Pepaya')
pandan_val_path = os.path.join(val_dir, 'Pandan')
nangka_val_path = os.path.join(val_dir, 'Nangka')
lidahbuaya_val_path = os.path.join(val_dir, 'Lidah buaya')
kemangi_val_path = os.path.join(val_dir, 'Kemangi')
jeruk_val_path = os.path.join(val_dir, 'Jeruk')
jambubiji_val_path = os.path.join(val_dir, 'Jambu biji')
belimbingwuluh_val_path = os.path.join(val_dir, 'Belimbing Wuluh')

len_sirih_train = len(os.listdir(sirih_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_jambubiji_train = len(os.listdir(jambubiji_train_path))
len_belimbingwuluh_train = len(os.listdir(belimbingwuluh_train_path))

len_sirih_val = len(os.listdir(sirih_val_path))
len_seledri_val = len(os.listdir(seledri_val_path))
len_pepaya_val = len(os.listdir(pepaya_val_path))
len_pandan_val = len(os.listdir(pandan_val_path))
len_nangka_val = len(os.listdir(nangka_val_path))
len_lidahbuaya_val = len(os.listdir(lidahbuaya_val_path))
len_kemangi_val = len(os.listdir(kemangi_val_path))
len_jeruk_val = len(os.listdir(jeruk_val_path))
len_jambubiji_val = len(os.listdir(jambubiji_val_path))
len_belimbingwuluh_val = len(os.listdir(belimbingwuluh_val_path))

print("Panjang train:", str(len_sirih_train + len_seledri_train + len_pepaya_train + len_pandan_train + len_nangka_train + len_lidahbuaya_train + len_kemangi_train + len_jeruk_train + len_jambubiji_train + len_belimbingwuluh_train))
print("Panjang validation:", str(len_sirih_val + len_seledri_val + len_pepaya_val + len_pandan_val + len_nangka_val + len_lidahbuaya_val + len_kemangi_val + len_jeruk_val + len_jambubiji_val + len_belimbingwuluh_val))

print('''\n==== Jumlah data train ====
Panjang data train Sirih: {}
Panjang data train Peledri: {}
Panjang data train Pepaya: {}
Panjang data train Pandan: {}
Panjang data train Nangka: {}
Panjang data train Lidah Buaya: {}
Panjang data train Kemangi: {}
Panjang data train Jeruk: {}
Panjang data train Jambu Biji: {}
Panjang data train Belimbing Wuluh: {}
'''.format(len_sirih_train, len_seledri_train, len_pepaya_train, len_pandan_train, len_nangka_train, len_lidahbuaya_train, len_kemangi_train, len_jeruk_train, len_jambubiji_train, len_belimbingwuluh_train))

print('''\n==== Jumlah data validation ====
Panjang data validation Sirih: {}
Panjang data validation Peledri: {}
Panjang data validation Pepaya: {}
Panjang data validation Pandan: {}
Panjang data validation Nangka: {}
Panjang data validation Lidah Buaya: {}
Panjang data validation Kemangi: {}
Panjang data validation Jeruk: {}
Panjang data validation Jambu Biji: {}
Panjang data validation Belimbing Wuluh: {}
'''.format(len_sirih_val, len_seledri_val, len_pepaya_val, len_pandan_val, len_nangka_val, len_lidahbuaya_val, len_kemangi_val, len_jeruk_val, len_jambubiji_val, len_belimbingwuluh_val))
# Out:
# Panjang train: 2590
# Panjang validation: 870
#
# ==== Jumlah data train ====
# Panjang data train Sirih: 259
# Panjang data train Peledri: 259
# Panjang data train Pepaya: 259
# Panjang data train Pandan: 259
# Panjang data train Nangka: 259
# Panjang data train Lidah Buaya: 259
# Panjang data train Kemangi: 259
# Panjang data train Jeruk: 259
# Panjang data train Jambu Biji: 259
# Panjang data train Belimbing Wuluh: 259
#
#
# ==== Jumlah data validation ====
# Panjang data validation Sirih: 87
# Panjang data validation Peledri: 87
# Panjang data validation Pepaya: 87
# Panjang data validation Pandan: 87
# Panjang data validation Nangka: 87
# Panjang data validation Lidah Buaya: 87
# Panjang data validation Kemangi: 87
# Panjang data validation Jeruk: 87
# Panjang data validation Jambu Biji: 87
# Panjang data validation Belimbing Wuluh: 87

# %%
train_sirih_fnames = os.listdir(sirih_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_jambubiji_fnames = os.listdir(jambubiji_train_path)
train_belimbingwuluh_fnames = os.listdir(belimbingwuluh_train_path)

print(train_sirih_fnames[:10])
print(train_seledri_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_pandan_fnames[:10])
print(train_nangka_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_jambubiji_fnames[:10])
print(train_belimbingwuluh_fnames[:10])
# Out:
# ['Sirih311.jpg', 'Sirih278.jpg', 'Sirih245.jpg', 'Sirih45.jpg', 'Sirih6.jpg', 'Sirih13.jpg', 'Sirih289.jpg', 'Sirih145.jpg', 'Sirih256.jpg', 'Sirih200.jpg']
# ['Seledri92.jpg', 'Seledri96.jpg', 'Seledri79.jpg', 'Seledri91.jpg', 'Seledri62.jpg', 'Seledri80.jpg', 'Seledri84.jpg', 'Seledri87.jpg', 'Seledri94.jpg', 'Seledri72.jpg']
# ['Pepaya234.jpg', 'Pepaya207.jpg', 'Pepaya78.jpg', 'Pepaya176.jpg', 'Pepaya236.jpg', 'Pepaya339.jpg', 'Pepaya169.jpg', 'Pepaya13.jpg', 'Pepaya11.jpg', 'Pepaya209.jpg']
# ['Pandan99.jpg', 'Pandan81.jpg', 'Pandan95.jpg', 'Pandan132.jpg', 'Pandan113.jpg', 'Pandan124.jpg', 'Pandan94.jpg', 'Pandan120.jpg', 'Pandan106.jpg', 'Pandan118.jpg']
# ['Nangka45.jpg', 'Nangka41.jpg', 'Nangka19.jpg', 'Nangka38.jpg', 'Nangka21.jpg', 'Nangka56.jpg', 'Nangka52.jpg', 'Nangka6.jpg', 'Nangka31.jpg', 'Nangka28.jpg']
# ['Lidah buaya113.jpg', 'Lidah buaya155.jpg', 'Lidah buaya135.jpg', 'Lidah buaya132.jpg', 'Lidah buaya143.jpg', 'Lidah buaya165.jpg', 'Lidah buaya130.jpg', 'Lidah buaya161.jpg', 'Lidah buaya127.jpg', 'Lidah buaya159.jpg']
# ['Kemangi77.jpg', 'Kemangi62.jpg', 'Kemangi66.jpg', 'Kemangi87.jpg', 'Kemangi94.jpg', 'Kemangi71.jpg', 'Kemangi84.jpg', 'Kemangi67.jpg', 'Kemangi88.jpg', 'Kemangi92.jpg']
# ['Jeruk202.jpg', 'Jeruk205.jpg', 'Jeruk210.jpg', 'Jeruk211.jpg', 'Jeruk213.jpg', 'Jeruk214.jpg', 'Jeruk215.jpg', 'Jeruk216.jpg', 'Jeruk218.jpg', 'Jeruk219.jpg']
# ['Jambu biji118.jpg', 'Jambu biji119.jpg', 'Jambu biji143.jpg', 'Jambu biji106.jpg', 'Jambu biji110.jpg', 'Jambu biji116.jpg', 'Jambu biji120.jpg', 'Jambu biji144.jpg', 'Jambu biji140.jpg', 'Jambu biji133.jpg']
# ['Belimbing Wuluh22.jpg', 'Belimbing Wuluh40.jpg', 'Belimbing Wuluh4.jpg', 'Belimbing Wuluh10.jpg', 'Belimbing Wuluh48.jpg', 'Belimbing Wuluh28.jpg', 'Belimbing Wuluh46.jpg', 'Belimbing Wuluh31.jpg', 'Belimbing Wuluh6.jpg', 'Belimbing Wuluh39.jpg']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 10
ncols = 8

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_sirih_pix = [os.path.join(sirih_train_path, fname)
                  for fname in train_sirih_fnames[ pic_index-8:pic_index]
                 ]
next_seledri_pix = [os.path.join(seledri_train_path, fname)
                  for fname in train_seledri_fnames[ pic_index-8:pic_index]
                 ]
next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
                    for fname in train_pepaya_fnames[ pic_index-8:pic_index]
                  ]
next_pandan_pix = [os.path.join(pandan_train_path, fname)
                    for fname in train_pandan_fnames[ pic_index-8:pic_index]
                  ]
next_nangka_pix = [os.path.join(nangka_train_path, fname)
                    for fname in train_nangka_fnames[ pic_index-8:pic_index]
                  ]
next_lidahbuaya_pix = [os.path.join(lidahbuaya_train_path, fname)
                    for fname in train_lidahbuaya_fnames[ pic_index-8:pic_index]
                  ]
next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
                    for fname in train_kemangi_fnames[ pic_index-8:pic_index]
                  ]
next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
                    for fname in train_jeruk_fnames[ pic_index-8:pic_index]
                  ]
next_jambubiji_pix = [os.path.join(jambubiji_train_path, fname)
                    for fname in train_jambubiji_fnames[ pic_index-8:pic_index]
                  ]
next_belimbingwuluh_pix = [os.path.join(belimbingwuluh_train_path, fname)
                    for fname in train_belimbingwuluh_fnames[ pic_index-8:pic_index]
                  ]

print(next_sirih_pix)
                
for i, img_path in enumerate(next_sirih_pix + next_seledri_pix + next_pepaya_pix + next_pandan_pix + next_nangka_pix + next_lidahbuaya_pix + next_kemangi_pix + next_jeruk_pix + next_jambubiji_pix + next_belimbingwuluh_pix):
  sp =  plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# ['/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih311.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih278.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih245.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih45.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih6.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih13.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih289.jpg', '/content/gdrive/MyDrive/Colab Notebooks/Kecerdasan Buatan/splitted/train/Sirih/Sirih145.jpg']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    rotation_range = 30,
    horizontal_flip = True,
    fill_mode = 'nearest',
)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'sparse',
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'sparse',
)
# Out:
# Found 2590 images belonging to 10 classes.
# Found 870 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense

# %%
image_size=[224,224]
vgg=VGG16(input_shape=image_size+[3], weights='imagenet', include_top=False)
vgg.output
# Out:
# <KerasTensor: shape=(None, 4, 4, 512) dtype=float32 (created by layer 'block5_pool')>

# %%
x=Flatten()(vgg.output)
prediction=Dense(10,activation='softmax')(x)
model=Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_1 (Dense)             (None, 10)                81930
#
# =================================================================
# Total params: 14,796,618
# Trainable params: 14,796,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nYour model accuration has been reached: 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=20,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=10,
      verbose=2,
      callbacks = [callbacks],
)
# Out:
# Epoch 1/100
# 20/20 - 21s - loss: 2.3619 - accuracy: 0.1101 - val_loss: 2.1895 - val_accuracy: 0.2313 - 21s/epoch - 1s/step
# Epoch 2/100
# 20/20 - 20s - loss: 1.9381 - accuracy: 0.3553 - val_loss: 1.6981 - val_accuracy: 0.5000 - 20s/epoch - 995ms/step
# Epoch 3/100
# 20/20 - 22s - loss: 1.4692 - accuracy: 0.5562 - val_loss: 1.2032 - val_accuracy: 0.6313 - 22s/epoch - 1s/step
# Epoch 4/100
# 20/20 - 20s - loss: 0.9382 - accuracy: 0.7000 - val_loss: 0.9923 - val_accuracy: 0.6125 - 20s/epoch - 1s/step
# Epoch 5/100
# 20/20 - 20s - loss: 0.9904 - accuracy: 0.6781 - val_loss: 1.1692 - val_accuracy: 0.6500 - 20s/epoch - 999ms/step
# Epoch 6/100
# 20/20 - 20s - loss: 0.8600 - accuracy: 0.6969 - val_loss: 0.6210 - val_accuracy: 0.8125 - 20s/epoch - 993ms/step
# Epoch 7/100
# 20/20 - 20s - loss: 0.6842 - accuracy: 0.7781 - val_loss: 0.4874 - val_accuracy: 0.8438 - 20s/epoch - 1s/step
# Epoch 8/100
# 20/20 - 19s - loss: 0.5031 - accuracy: 0.8031 - val_loss: 0.4317 - val_accuracy: 0.8375 - 19s/epoch - 939ms/step
# Epoch 9/100
# 20/20 - 20s - loss: 0.5579 - accuracy: 0.8396 - val_loss: 0.6889 - val_accuracy: 0.7437 - 20s/epoch - 995ms/step
# Epoch 10/100
# 20/20 - 20s - loss: 0.4362 - accuracy: 0.8522 - val_loss: 0.4308 - val_accuracy: 0.8375 - 20s/epoch - 994ms/step
# Epoch 11/100
# 20/20 - 20s - loss: 0.4042 - accuracy: 0.8594 - val_loss: 0.4735 - val_accuracy: 0.8313 - 20s/epoch - 998ms/step
# Epoch 12/100
# 20/20 - 20s - loss: 0.3545 - accuracy: 0.8906 - val_loss: 0.4503 - val_accuracy: 0.8438 - 20s/epoch - 978ms/step
# Epoch 13/100
# 20/20 - 22s - loss: 0.4166 - accuracy: 0.8562 - val_loss: 0.3609 - val_accuracy: 0.8625 - 22s/epoch - 1s/step
# Epoch 14/100
# 20/20 - 19s - loss: 0.3916 - accuracy: 0.8750 - val_loss: 0.4520 - val_accuracy: 0.8687 - 19s/epoch - 965ms/step
# Epoch 15/100
# 20/20 - 20s - loss: 0.3665 - accuracy: 0.8906 - val_loss: 0.3130 - val_accuracy: 0.8875 - 20s/epoch - 987ms/step
# Epoch 16/100
# 20/20 - 19s - loss: 0.3333 - accuracy: 0.8875 - val_loss: 0.3030 - val_accuracy: 0.9187 - 19s/epoch - 934ms/step
# Epoch 17/100
# 20/20 - 22s - loss: 0.2723 - accuracy: 0.9125 - val_loss: 0.2224 - val_accuracy: 0.9375 - 22s/epoch - 1s/step
# Epoch 18/100
# 20/20 - 19s - loss: 0.2890 - accuracy: 0.9000 - val_loss: 0.1945 - val_accuracy: 0.9187 - 19s/epoch - 967ms/step
# Epoch 19/100
# 20/20 - 23s - loss: 0.2215 - accuracy: 0.9250 - val_loss: 0.2521 - val_accuracy: 0.9375 - 23s/epoch - 1s/step
# Epoch 20/100
# 20/20 - 22s - loss: 0.2450 - accuracy: 0.9312 - val_loss: 0.3760 - val_accuracy: 0.8875 - 22s/epoch - 1s/step
# Epoch 21/100
# 20/20 - 23s - loss: 0.2421 - accuracy: 0.9125 - val_loss: 0.2761 - val_accuracy: 0.9000 - 23s/epoch - 1s/step
# Epoch 22/100
# 20/20 - 20s - loss: 0.2563 - accuracy: 0.8962 - val_loss: 0.2156 - val_accuracy: 0.9312 - 20s/epoch - 1s/step
# Epoch 23/100
# 20/20 - 20s - loss: 0.2494 - accuracy: 0.9219 - val_loss: 0.2057 - val_accuracy: 0.9375 - 20s/epoch - 1s/step
# Epoch 24/100
# 20/20 - 20s - loss: 0.2784 - accuracy: 0.9156 - val_loss: 0.1773 - val_accuracy: 0.9250 - 20s/epoch - 1s/step
# Epoch 25/100
# 20/20 - 20s - loss: 0.1726 - accuracy: 0.9438 - val_loss: 0.1562 - val_accuracy: 0.9438 - 20s/epoch - 1s/step
# Epoch 26/100
# 20/20 - 21s - loss: 0.2016 - accuracy: 0.9250 - val_loss: 0.1027 - val_accuracy: 0.9688 - 21s/epoch - 1s/step
# Epoch 27/100
# 20/20 - 22s - loss: 0.2591 - accuracy: 0.9000 - val_loss: 0.1972 - val_accuracy: 0.9250 - 22s/epoch - 1s/step
# Epoch 28/100
# 20/20 - 20s - loss: 0.1394 - accuracy: 0.9469 - val_loss: 0.2402 - val_accuracy: 0.9187 - 20s/epoch - 1s/step
# Epoch 29/100
# 20/20 - 20s - loss: 0.2063 - accuracy: 0.9281 - val_loss: 0.3064 - val_accuracy: 0.8875 - 20s/epoch - 1s/step
# Epoch 30/100
# 20/20 - 20s - loss: 0.1784 - accuracy: 0.9438 - val_loss: 0.1183 - val_accuracy: 0.9625 - 20s/epoch - 984ms/step
# Epoch 31/100
# 20/20 - 21s - loss: 0.1682 - accuracy: 0.9406 - val_loss: 0.2054 - val_accuracy: 0.9312 - 21s/epoch - 1s/step
# Epoch 32/100
# 20/20 - 21s - loss: 0.1350 - accuracy: 0.9500 - val_loss: 0.1786 - val_accuracy: 0.9438 - 21s/epoch - 1s/step
# Epoch 33/100
# 20/20 - 21s - loss: 0.1051 - accuracy: 0.9531 - val_loss: 0.1731 - val_accuracy: 0.9438 - 21s/epoch - 1s/step
# Epoch 34/100
# 20/20 - 21s - loss: 0.1791 - accuracy: 0.9344 - val_loss: 0.2446 - val_accuracy: 0.9125 - 21s/epoch - 1s/step
# Epoch 35/100
# 20/20 - 19s - loss: 0.2873 - accuracy: 0.8906 - val_loss: 0.2072 - val_accuracy: 0.9312 - 19s/epoch - 958ms/step
# Epoch 36/100
# 20/20 - 20s - loss: 0.1449 - accuracy: 0.9531 - val_loss: 0.2398 - val_accuracy: 0.9312 - 20s/epoch - 1s/step
# Epoch 37/100
# 20/20 - 21s - loss: 0.1225 - accuracy: 0.9469 - val_loss: 0.0820 - val_accuracy: 0.9875 - 21s/epoch - 1s/step
# Epoch 38/100
# 20/20 - 20s - loss: 0.1038 - accuracy: 0.9563 - val_loss: 0.1274 - val_accuracy: 0.9500 - 20s/epoch - 1s/step
# Epoch 39/100
# 20/20 - 19s - loss: 0.1148 - accuracy: 0.9563 - val_loss: 0.2586 - val_accuracy: 0.9062 - 19s/epoch - 943ms/step
# Epoch 40/100
# 20/20 - 21s - loss: 0.1918 - accuracy: 0.9375 - val_loss: 0.4007 - val_accuracy: 0.8562 - 21s/epoch - 1s/step
# Epoch 41/100
# 20/20 - 19s - loss: 0.1754 - accuracy: 0.9497 - val_loss: 0.2821 - val_accuracy: 0.9000 - 19s/epoch - 951ms/step
# Epoch 42/100
# 20/20 - 20s - loss: 0.1667 - accuracy: 0.9406 - val_loss: 0.1547 - val_accuracy: 0.9438 - 20s/epoch - 1s/step
# Epoch 43/100
# 20/20 - 21s - loss: 0.1503 - accuracy: 0.9563 - val_loss: 0.2338 - val_accuracy: 0.9250 - 21s/epoch - 1s/step
# Epoch 44/100
# 20/20 - 18s - loss: 0.1621 - accuracy: 0.9594 - val_loss: 0.2013 - val_accuracy: 0.8938 - 18s/epoch - 906ms/step
# Epoch 45/100
# 20/20 - 20s - loss: 0.1341 - accuracy: 0.9528 - val_loss: 0.2438 - val_accuracy: 0.9000 - 20s/epoch - 990ms/step
# Epoch 46/100
# 20/20 - 21s - loss: 0.1276 - accuracy: 0.9594 - val_loss: 0.1724 - val_accuracy: 0.9375 - 21s/epoch - 1s/step
# Epoch 47/100
# 20/20 - 21s - loss: 0.1208 - accuracy: 0.9750 - val_loss: 0.1553 - val_accuracy: 0.9563 - 21s/epoch - 1s/step
# Epoch 48/100
# 20/20 - 21s - loss: 0.0844 - accuracy: 0.9688 - val_loss: 0.1210 - val_accuracy: 0.9438 - 21s/epoch - 1s/step
# Epoch 49/100
# 20/20 - 20s - loss: 0.1180 - accuracy: 0.9560 - val_loss: 0.2876 - val_accuracy: 0.8875 - 20s/epoch - 989ms/step
# Epoch 50/100
# 20/20 - 20s - loss: 0.1613 - accuracy: 0.9312 - val_loss: 0.1870 - val_accuracy: 0.9500 - 20s/epoch - 990ms/step
# Epoch 51/100
# 20/20 - 20s - loss: 0.1725 - accuracy: 0.9375 - val_loss: 0.1233 - val_accuracy: 0.9438 - 20s/epoch - 988ms/step
# Epoch 52/100
# 20/20 - 21s - loss: 0.1319 - accuracy: 0.9625 - val_loss: 0.2753 - val_accuracy: 0.9187 - 21s/epoch - 1s/step
# Epoch 53/100
# 20/20 - 19s - loss: 0.0772 - accuracy: 0.9812 - val_loss: 0.1342 - val_accuracy: 0.9688 - 19s/epoch - 935ms/step
# Epoch 54/100
# 20/20 - 21s - loss: 0.0980 - accuracy: 0.9625 - val_loss: 0.1062 - val_accuracy: 0.9563 - 21s/epoch - 1s/step
# Epoch 55/100
# 20/20 - 21s - loss: 0.1040 - accuracy: 0.9750 - val_loss: 0.0831 - val_accuracy: 0.9625 - 21s/epoch - 1s/step
# Epoch 56/100
# 20/20 - 20s - loss: 0.1257 - accuracy: 0.9469 - val_loss: 0.0836 - val_accuracy: 0.9937 - 20s/epoch - 986ms/step
# Epoch 57/100
# 20/20 - 20s - loss: 0.1091 - accuracy: 0.9688 - val_loss: 0.1391 - val_accuracy: 0.9500 - 20s/epoch - 987ms/step
# Epoch 58/100
# 20/20 - 19s - loss: 0.0972 - accuracy: 0.9654 - val_loss: 0.1449 - val_accuracy: 0.9625 - 19s/epoch - 969ms/step
# Epoch 59/100
# 20/20 - 19s - loss: 0.0826 - accuracy: 0.9688 - val_loss: 0.1852 - val_accuracy: 0.9312 - 19s/epoch - 945ms/step
# Epoch 60/100
# 20/20 - 21s - loss: 0.0974 - accuracy: 0.9688 - val_loss: 0.1037 - val_accuracy: 0.9750 - 21s/epoch - 1s/step
# Epoch 61/100
# 20/20 - 22s - loss: 0.0734 - accuracy: 0.9844 - val_loss: 0.2259 - val_accuracy: 0.9187 - 22s/epoch - 1s/step
# Epoch 62/100
# 20/20 - 23s - loss: 0.1256 - accuracy: 0.9406 - val_loss: 0.2157 - val_accuracy: 0.9250 - 23s/epoch - 1s/step
# Epoch 63/100
# 20/20 - 20s - loss: 0.0791 - accuracy: 0.9717 - val_loss: 0.1369 - val_accuracy: 0.9563 - 20s/epoch - 1s/step
# Epoch 64/100
# 20/20 - 21s - loss: 0.0624 - accuracy: 0.9750 - val_loss: 0.0761 - val_accuracy: 0.9625 - 21s/epoch - 1s/step
# Epoch 65/100
# 20/20 - 20s - loss: 0.0879 - accuracy: 0.9750 - val_loss: 0.0398 - val_accuracy: 0.9875 - 20s/epoch - 988ms/step
# Epoch 66/100
# 20/20 - 22s - loss: 0.0724 - accuracy: 0.9844 - val_loss: 0.0684 - val_accuracy: 0.9750 - 22s/epoch - 1s/step
# Epoch 67/100
# 20/20 - 20s - loss: 0.0819 - accuracy: 0.9812 - val_loss: 0.0609 - val_accuracy: 0.9750 - 20s/epoch - 976ms/step
# Epoch 68/100
# 20/20 - 20s - loss: 0.0686 - accuracy: 0.9750 - val_loss: 0.1064 - val_accuracy: 0.9563 - 20s/epoch - 978ms/step
# Epoch 69/100
# 20/20 - 21s - loss: 0.0856 - accuracy: 0.9719 - val_loss: 0.2397 - val_accuracy: 0.9187 - 21s/epoch - 1s/step
# Epoch 70/100
# 20/20 - 21s - loss: 0.0884 - accuracy: 0.9750 - val_loss: 0.1752 - val_accuracy: 0.9438 - 21s/epoch - 1s/step
# Epoch 71/100
#
# Your model accuration has been reached: 99%
# 20/20 - 21s - loss: 0.0659 - accuracy: 0.9906 - val_loss: 0.1487 - val_accuracy: 0.9563 - 21s/epoch - 1s/step

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training dan Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label='Training oss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training dan validation loss')
plt.legend(loc=0)

plt.show()

# %%
from sklearn.metrics import f1_score, recall_score, accuracy_score
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np

sns.set(style='whitegrid')

def my_metrics(y_true, y_pred):
  accuracy = accuracy_score(y_true, y_pred)
  precision = precision_score(y_true, y_pred, average='weighted')
  f1Score = f1_score(y_true, y_pred, average='weighted')
  print("Accuracy : {}".format(accuracy))
  print("Precision : {}".format(precision))
  print("f1Score : {}".format(f1Score))
  cm = confusion_matrix(y_true, y_pred)
  print(cm)
  return accuracy, precision, f1Score

predictions = model.predict(validation_generator)
yPredictions = predictions > 0.5
true_classes = validation_generator.classes
class_names = validation_generator.class_indices
Cmatrix_test = confusion_matrix(true_classes, yPredictions)

print(classification_report(true_classes, yPredictions, target_names=class_names))

# testAcc, testPrec, testFScore = my_metrics(true_classes, yPredictions)

# plt.figure(figsize=(10,10))
# ax = plt.subplot()
# data = np.asarray(Cmatrix_test).reshape(2,2)
# sns.heatmap(data, annot=True, fmt='', ax=ax, cmap=plt.cm.Reds)
# ax.set_xlabel('Predicted labels')
# ax.set_ylabel('True labels')
# ax.set_title('Confusion Matrix')
# ax.xaxis.set_ticklabels(class_names)
# ax.yaxis.set_ticklabels(class_names)
# plt.title('Confusion Matrix Test', fontsize=14)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-cd110cdd4dde> in <module>()
#      21 true_classes = validation_generator.classes
#      22 class_names = validation_generator.class_indices
# ---> 23 Cmatrix_test = confusion_matrix(true_classes, yPredictions)
#      24
#      25 print(classification_report(true_classes, yPredictions, target_names=class_names))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of multiclass and multilabel-indicator targets

# %%
import numpy as np 
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()
 
for fn in uploaded.keys():
  path = fn
  img = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)

  class_list = os.listdir(train_dir)
  
  if classes[0][0]:
    prediction="Belimbing Wuluh"
  elif classes[0][1]:
    prediction="Jambu Biji"
  elif classes[0][2]:
    prediction="Jeruk"
  elif classes[0][3]:
    prediction="Kemangi"
  elif classes[0][4]:
    prediction="Lidah Buaya"
  elif classes[0][5]:
    prediction="Nangka"
  elif classes[0][6]:
    prediction="Pandan"
  elif classes[0][7]:
    prediction="Pepaya"
  elif classes[0][8]:
    prediction="Seledri"
  elif classes[0][9]:
    prediction="Sirih"
  else:
    prediction="[Undefined]"
  print(prediction)
# Out:
#      <input type="file" id="files-5c7d4f47-df11-4aed-8dd4-9edd38ff9403" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c7d4f47-df11-4aed-8dd4-9edd38ff9403">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.jpg to images.jpg
# Kemangi
